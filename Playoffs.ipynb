# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.61 Safari/537.36"}

# %%
def add_game(games, resume):
    regular_game = 1
    for game in games:
        total = {}
    
        try:
            game['id']
            data = game.findNext('td').findNext('td').find('a').contents[0]
            serie = data.findNext('td').find('a').contents[0]
            team = serie.findNext('td').find('a').contents[0]
            opp = team.findNext('td').findNext('td').find('a').contents[0]
            game_number = opp.findNext('td').find('a').contents[0]
            result = game_number.findNext('td').contents[0]
            started = result.findNext('td').contents[0]
            minutes = started.findNext('td').contents[0]

            fg = minutes.findNext('td').contents [0]
            fga = fg.findNext('td').contents[0]
            fgp = fga.findNext('td').contents[0]

            fg3 = fgp.findNext('td').contents[0]
            fg3a = fg3.findNext('td').contents[0]
            fg3p = fg3a.findNext('td').getText()

            ft = fg3a.findNext('td').findNext('td').contents[0]
            fta = ft.findNext('td').contents[0]
            ftp = fta.findNext('td').getText()

            orb = fta.findNext('td').findNext('td').contents[0]
            drb = orb.findNext('td').contents[0]
            totrb = drb.findNext('td').contents[0]
            ast = totrb.findNext('td').contents[0]
            stl = ast.findNext('td').contents[0]
            blk =stl.findNext('td').contents[0]
            tov = blk.findNext('td').contents[0]
            fouls = tov.findNext('td').contents[0]
            points = fouls.findNext('td').contents[0]

            total['game'] = regular_game
            total['data'] = data 
            total['serie'] = serie 
            total['team'] = team 
            total['opp'] = opp  
            total['game_number'] = game_number
            total['result'] = result 
            total['started'] = started 
            total['minutes'] = minutes 

            total['fg'] = fg
            total['fga'] = fga
            total['fgp'] = fgp 

            total['fg3'] = fg3 
            total['fg3a'] = fg3a 
            total['fg3p'] = fg3p

            total['ft'] = ft
            total['fta'] = fta
            total['ftp'] = ftp

            total['orb'] = orb
            total['drb'] = drb 
            total['totrb'] = totrb 
            total['ast'] = ast  
            total['stl'] = stl
            total['blk'] = blk
            total['tov'] = tov
            total['fouls'] = fouls
            total['points'] = points


            regular_game += 1
            resume.append(total)
        except:
            game = game

# %%
resume_jordan = []
url = "https://www.basketball-reference.com/players/j/jordami01/gamelog-playoffs/"


response = requests.get(url, headers=headers)
text = response.text
soup = BeautifulSoup(text, 'html.parser')
    

list_games = soup.find('table', id ='pgl_basic_playoffs')
list_games = list_games.find('tbody')



games = list_games.findAll('tr')
add_game(games, resume_jordan)

# %%
resume_jordan
# Out:
# [{'game': 1,
#   'data': '1985-04-19',
#   'serie': 'EC1',
#   'team': 'CHI',
#   'opp': 'MIL',
#   'game_number': '1',
#   'result': 'L (-9)',
#   'started': '1',
#   'minutes': '44:00',
#   'fg': '7',
#   'fga': '19',
#   'fgp': '.368',
#   'fg3': '0',
#   'fg3a': '1',
#   'fg3p': '.000',
#   'ft': '9',
#   'fta': '10',
#   'ftp': '.900',
#   'orb': '1',
#   'drb': '3',
#   'totrb': '4',
#   'ast': '10',
#   'stl': '3',
#   'blk': '0',
#   'tov': '1',
#   'fouls': '3',
#   'points': '23'},
#  {'game': 2,
#   'data': '1985-04-21',
#   'serie': 'EC1',
#   'team': 'CHI',
#   'opp': 'MIL',
#   'game_number': '2',
#   'result': 'L (-7)',
#   'started': '1',
#   'minutes': '43:00',
#   'fg': '9',
#   'fga': '17',
#   'fgp': '.529',
#   'fg3': '1',
#   'fg3a': '4',
#   'fg3p': '.250',
#   'ft': '11',
#   'fta': '12',
#   'ftp': '.917',
#   'orb': '1',
#   'drb': '3',
#   'totrb': '4',
#   'ast': '12',
#   'stl': '2',
#   'blk': '0',
#   'tov': '7',
#   'fouls': '5',
#   'points': '30'},
#  {'game': 3,
#   'data': '1985-04-24',
#   'serie': 'EC1',
#   'team': 'CHI',
#   'opp': 'MIL',
#   'game_number': '3',
#   'result': 'W (+2)',
#   'started': '1',
#   'minutes': '42:00',
#   'fg': '12',
#   'fga': '26',
#   'fgp': '.462',
#   'fg3': '0',
#   'fg3a': '1',
#   'fg3p': '.000',
#   'ft': '11',
#   'fta': '16',
#   'ftp': '.688',
#   'orb': '3',
#   'drb': '5',
#   'totrb': '8',
#   'ast': '7',
#   'stl': '4',
#   'blk': '1',
#   'tov': '3',
#   'fouls': '4',
#   'points': '35'},
#  {'game': 4,
#   'data': '1985-04-26',
#   'serie': 'EC1',
#   'team': 'CHI',
#   'opp': 'MIL',
#   'game_number': '4',
#   'result': 'L (-8)',
#   'started': '1',
#   'minutes': '42:00',
#   'fg': '6',
#   'fga': '16',
#   'fgp': '.375',
#   'fg3': '0',
#   'fg3a': '2',
#   'fg3p': '.000',
#   'ft': '17',
#   'fta': '20',
#   'ftp': '.850',
#   'orb': '2',
#   'drb': '5',
#   'totrb': '7',
#   'ast': '5',
#   'stl': '2',
#   'blk': '3',
#   'tov': '4',
#   'fouls': '3',
#   'points': '29'},
#  {'game': 5,
#   'data': '1986-04-17',
#   'serie': 'EC1',
#   'team': 'CHI',
#   'opp': 'BOS',
#   'game_number': '1',
#   'result': 'L (-19)',
#   'started': '1',
#   'minutes': '43:00',
#   'fg': '18',
#   'fga': '36',
#   'fgp': '.500',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3p': '',
#   'ft': '13',
#   'fta': '15',
#   'ftp': '.867',
#   'orb': '0',
#   'drb': '4',
#   'totrb': '4',
#   'ast': '2',
#   'stl': '2',
#   'blk': '1',
#   'tov': '5',
#   'fouls': '3',
#   'points': '49'},
#  {'game': 6,
#   'data': '1986-04-20',
#   'serie': 'EC1',
#   'team': 'CHI',
#   'opp': 'BOS',
#   'game_number': '2',
#   'result': 'L (-4)',
#   'started': '1',
#   'minutes': '53:00',
#   'fg': '22',
#   'fga': '41',
#   'fgp': '.537',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3p': '',
#   'ft': '19',
#   'fta': '21',
#   'ftp': '.905',
#   'orb': '1',
#   'drb': '4',
#   'totrb': '5',
#   'ast': '6',
#   'stl': '3',
#   'blk': '2',
#   'tov': '4',
#   'fouls': '4',
#   'points': '63'},
#  {'game': 7,
#   'data': '1986-04-22',
#   'serie': 'EC1',
#   'team': 'CHI',
#   'opp': 'BOS',
#   'game_number': '3',
#   'result': 'L (-18)',
#   'started': '1',
#   'minutes': '39:00',
#   'fg': '8',
#   'fga': '18',
#   'fgp': '.444',
#   'fg3': '1',
#   'fg3a': '1',
#   'fg3p': '1.000',
#   'ft': '2',
#   'fta': '3',
#   'ftp': '.667',
#   'orb': '4',
#   'drb': '6',
#   'totrb': '10',
#   'ast': '9',
#   'stl': '2',
#   'blk': '1',
#   'tov': '5',
#   'fouls': '6',
#   'points': '19'},
#  {'game': 8,
#   'data': '1987-04-23',
#   'serie': 'EC1',
#   'team': 'CHI',
#   'opp': 'BOS',
#   'game_number': '1',
#   'result': 'L (-4)',
#   'started': '1',
#   'minutes': '44:00',
#   'fg': '12',
#   'fga': '25',
#   'fgp': '.480',
#   'fg3': '0',
#   'fg3a': '1',
#   'fg3p': '.000',
#   'ft': '11',
#   'fta': '11',
#   'ftp': '1.000',
#   'orb': '0',
#   'drb': '6',
#   'totrb': '6',
#   'ast': '7',
#   'stl': '4',
#   'blk': '2',
#   'tov': '2',
#   'fouls': '4',
#   'points': '35'},
#  {'game': 9,
#   'data': '1987-04-26',
#   'serie': 'EC1',
#   'team': 'CHI',
#   'opp': 'BOS',
#   'game_number': '2',
#   'result': 'L (-9)',
#   'started': '1',
#   'minutes': '45:00',
#   'fg': '14',
#   'fga': '29',
#   'fgp': '.483',
#   'fg3': '2',
#   'fg3a': '3',
#   'fg3p': '.667',
#   'ft': '12',
#   'fta': '14',
#   'ftp': '.857',
#   'orb': '1',
#   'drb': '3',
#   'totrb': '4',
#   'ast': '4',
#   'stl': '0',
#   'blk': '4',
#   'tov': '4',
#   'fouls': '3',
#   'points': '42'},
#  {'game': 10,
#   'data': '1987-04-28',
#   'serie': 'EC1',
#   'team': 'CHI',
#   'opp': 'BOS',
#   'game_number': '3',
#   'result': 'L (-11)',
#   'started': '1',
#   'minutes': '39:00',
#   'fg': '9',
#   'fga': '30',
#   'fgp': '.300',
#   'fg3': '0',
#   'fg3a': '1',
#   'fg3p': '.000',
#   'ft': '12',
#   'fta': '14',
#   'ftp': '.857',
#   'orb': '6',
#   'drb': '5',
#   'totrb': '11',
#   'ast': '7',
#   'stl': '2',
#   'blk': '1',
#   'tov': '2',
#   'fouls': '4',
#   'points': '30'},
#  {'game': 11,
#   'data': '1988-04-28',
#   'serie': 'EC1',
#   'team': 'CHI',
#   'opp': 'CLE',
#   'game_number': '1',
#   'result': 'W (+11)',
#   'started': '1',
#   'minutes': '44:00',
#   'fg': '19',
#   'fga': '35',
#   'fgp': '.543',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3p': '',
#   'ft': '12',
#   'fta': '12',
#   'ftp': '1.000',
#   'orb': '1',
#   'drb': '6',
#   'totrb': '7',
#   'ast': '2',
#   'stl': '2',
#   'blk': '2',
#   'tov': '5',
#   'fouls': '3',
#   'points': '50'},
#  {'game': 12,
#   'data': '1988-05-01',
#   'serie': 'EC1',
#   'team': 'CHI',
#   'opp': 'CLE',
#   'game_number': '2',
#   'result': 'W (+5)',
#   'started': '1',
#   'minutes': '44:00',
#   'fg': '24',
#   'fga': '45',
#   'fgp': '.533',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3p': '',
#   'ft': '7',
#   'fta': '7',
#   'ftp': '1.000',
#   'orb': '3',
#   'drb': '3',
#   'totrb': '6',
#   'ast': '3',
#   'stl': '4',
#   'blk': '1',
#   'tov': '1',
#   'fouls': '4',
#   'points': '55'},
#  {'game': 13,
#   'data': '1988-05-03',
#   'serie': 'EC1',
#   'team': 'CHI',
#   'opp': 'CLE',
#   'game_number': '3',
#   'result': 'L (-8)',
#   'started': '1',
#   'minutes': '44:00',
#   'fg': '12',
#   'fga': '25',
#   'fgp': '.480',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3p': '',
#   'ft': '14',
#   'fta': '15',
#   'ftp': '.933',
#   'orb': '2',
#   'drb': '3',
#   'totrb': '5',
#   'ast': '9',
#   'stl': '2',
#   'blk': '1',
#   'tov': '4',
#   'fouls': '5',
#   'points': '38'},
#  {'game': 14,
#   'data': '1988-05-05',
#   'serie': 'EC1',
#   'team': 'CHI',
#   'opp': 'CLE',
#   'game_number': '4',
#   'result': 'L (-6)',
#   'started': '1',
#   'minutes': '42:00',
#   'fg': '18',
#   'fga': '25',
#   'fgp': '.720',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3p': '',
#   'ft': '8',
#   'fta': '9',
#   'ftp': '.889',
#   'orb': '2',
#   'drb': '3',
#   'totrb': '5',
#   'ast': '4',
#   'stl': '4',
#   'blk': '2',
#   'tov': '4',
#   'fouls': '6',
#   'points': '44'},
#  {'game': 15,
#   'data': '1988-05-08',
#   'serie': 'EC1',
#   'team': 'CHI',
#   'opp': 'CLE',
#   'game_number': '5',
#   'result': 'W (+6)',
#   'started': '1',
#   'minutes': '43:00',
#   'fg': '12',
#   'fga': '22',
#   'fgp': '.545',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3p': '',
#   'ft': '15',
#   'fta': '18',
#   'ftp': '.833',
#   'orb': '1',
#   'drb': '3',
#   'totrb': '4',
#   'ast': '6',
#   'stl': '2',
#   'blk': '2',
#   'tov': '7',
#   'fouls': '4',
#   'points': '39'},
#  {'game': 16,
#   'data': '1988-05-10',
#   'serie': 'ECS',
#   'team': 'CHI',
#   'opp': 'DET',
#   'game_number': '1',
#   'result': 'L (-11)',
#   'started': '1',
#   'minutes': '40:00',
#   'fg': '10',
#   'fga': '22',
#   'fgp': '.455',
#   'fg3': '0',
#   'fg3a': '1',
#   'fg3p': '.000',
#   'ft': '9',
#   'fta': '10',
#   'ftp': '.900',
#   'orb': '5',
#   'drb': '6',
#   'totrb': '11',
#   'ast': '6',
#   'stl': '0',
#   'blk': '1',
#   'tov': '5',
#   'fouls': '4',
#   'points': '29'},
#  {'game': 17,
#   'data': '1988-05-12',
#   'serie': 'ECS',
#   'team': 'CHI',
#   'opp': 'DET',
#   'game_number': '2',
#   'result': 'W (+10)',
#   'started': '1',
#   'minutes': '44:00',
#   'fg': '14',
#   'fga': '22',
#   'fgp': '.636',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3p': '',
#   'ft': '8',
#   'fta': '10',
#   'ftp': '.800',
#   'orb': '4',
#   'drb': '7',
#   'totrb': '11',
#   'ast': '1',
#   'stl': '1',
#   'blk': '1',
#   'tov': '2',
#   'fouls': '5',
#   'points': '36'},
#  {'game': 18,
#   'data': '1988-05-14',
#   'serie': 'ECS',
#   'team': 'CHI',
#   'opp': 'DET',
#   'game_number': '3',
#   'result': 'L (-22)',
#   'started': '1',
#   'minutes': '38:00',
#   'fg': '8',
#   'fga': '20',
#   'fgp': '.400',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3p': '',
#   'ft': '8',
#   'fta': '9',
#   'ftp': '.889',
#   'orb': '1',
#   'drb': '6',
#   'totrb': '7',
#   'ast': '3',
#   'stl': '1',
#   'blk': '1',
#   'tov': '5',
#   'fouls': '3',
#   'points': '24'},
#  {'game': 19,
#   'data': '1988-05-15',
#   'serie': 'ECS',
#   'team': 'CHI',
#   'opp': 'DET',
#   'game_number': '4',
#   'result': 'L (-19)',
#   'started': '1',
#   'minutes': '45:00',
#   'fg': '11',
#   'fga': '22',
#   'fgp': '.500',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3p': '',
#   'ft': '1',
#   'fta': '2',
#   'ftp': '.500',
#   'orb': '2',
#   'drb': '5',
#   'totrb': '7',
#   'ast': '5',
#   'stl': '6',
#   'blk': '0',
#   'tov': '3',
#   'fouls': '0',
#   'points': '23'},
#  {'game': 20,
#   'data': '1988-05-18',
#   'serie': 'ECS',
#   'team': 'CHI',
#   'opp': 'DET',
#   'game_number': '5',
#   'result': 'L (-7)',
#   'started': '1',
#   'minutes': '43:00',
#   'fg': '10',
#   'fga': '22',
#   'fgp': '.455',
#   'fg3': '1',
#   'fg3a': '2',
#   'fg3p': '.500',
#   'ft': '4',
#   'fta': '7',
#   'ftp': '.571',
#   'orb': '2',
#   'drb': '6',
#   'totrb': '8',
#   'ast': '8',
#   'stl': '2',
#   'blk': '0',
#   'tov': '3',
#   'fouls': '4',
#   'points': '25'},
#  {'game': 21,
#   'data': '1989-04-28',
#   'serie': 'EC1',
#   'team': 'CHI',
#   'opp': 'CLE',
#   'game_number': '1',
#   'result': 'W (+7)',
#   'started': '1',
#   'minutes': '40:00',
#   'fg': '12',
#   'fga': '21',
#   'fgp': '.571',
#   'fg3': '0',
#   'fg3a': '1',
#   'fg3p': '.000',
#   'ft': '7',
#   'fta': '8',
#   'ftp': '.875',
#   'orb': '0',
#   'drb': '5',
#   'totrb': '5',
#   'ast': '11',
#   'stl': '4',
#   'blk': '1',
#   'tov': '6',
#   'fouls': '5',
#   'points': '31'},
#  {'game': 22,
#   'data': '1989-04-30',
#   'serie': 'EC1',
#   'team': 'CHI',
#   'opp': 'CLE',
#   'game_number': '2',
#   'result': 'L (-8)',
#   'started': '1',
#   'minutes': '44:00',
#   'fg': '10',
#   'fga': '22',
#   'fgp': '.455',
#   'fg3': '0',
#   'fg3a': '1',
#   'fg3p': '.000',
#   'ft': '10',
#   'fta': '10',
#   'ftp': '1.000',
#   'orb': '3',
#   'drb': '2',
#   'totrb': '5',
#   'ast': '10',
#   'stl': '2',
#   'blk': '0',
#   'tov': '7',
#   'fouls': '2',
#   'points': '30'},
#  {'game': 23,
#   'data': '1989-05-03',
#   'serie': 'EC1',
#   'team': 'CHI',
#   'opp': 'CLE',
#   'game_number': '3',
#   'result': 'W (+7)',
#   'started': '1',
#   'minutes': '39:00',
#   'fg': '18',
#   'fga': '34',
#   'fgp': '.529',
#   'fg3': '1',
#   'fg3a': '1',
#   'fg3p': '1.000',
#   'ft': '7',
#   'fta': '9',
#   'ftp': '.778',
#   'orb': '2',
#   'drb': '5',
#   'totrb': '7',
#   'ast': '10',
#   'stl': '5',
#   'blk': '1',
#   'tov': '5',
#   'fouls': '4',
#   'points': '44'},
#  {'game': 24,
#   'data': '1989-05-05',
#   'serie': 'EC1',
#   'team': 'CHI',
#   'opp': 'CLE',
#   'game_number': '4',
#   'result': 'L (-3)',
#   'started': '1',
#   'minutes': '43:00',
#   'fg': '14',
#   'fga': '28',
#   'fgp': '.500',
#   'fg3': '0',
#   'fg3a': '1',
#   'fg3p': '.000',
#   'ft': '22',
#   'fta': '27',
#   'ftp': '.815',
#   'orb': '0',
#   'drb': '3',
#   'totrb': '3',
#   'ast': '4',
#   'stl': '3',
#   'blk': '0',
#   'tov': '1',
#   'fouls': '6',
#   'points': '50'},
#  {'game': 25,
#   'data': '1989-05-07',
#   'serie': 'EC1',
#   'team': 'CHI',
#   'opp': 'CLE',
#   'game_number': '5',
#   'result': 'W (+1)',
#   'started': '1',
#   'minutes': '44:00',
#   'fg': '17',
#   'fga': '32',
#   'fgp': '.531',
#   'fg3': '1',
#   'fg3a': '1',
#   'fg3p': '1.000',
#   'ft': '9',
#   'fta': '13',
#   'ftp': '.692',
#   'orb': '3',
#   'drb': '6',
#   'totrb': '9',
#   'ast': '6',
#   'stl': '1',
#   'blk': '0',
#   'tov': '2',
#   'fouls': '3',
#   'points': '44'},
#  {'game': 26,
#   'data': '1989-05-09',
#   'serie': 'ECS',
#   'team': 'CHI',
#   'opp': 'NYK',
#   'game_number': '1',
#   'result': 'W (+11)',
#   'started': '1',
#   'minutes': '46:00',
#   'fg': '11',
#   'fga': '17',
#   'fgp': '.647',
#   'fg3': '1',
#   'fg3a': '2',
#   'fg3p': '.500',
#   'ft': '11',
#   'fta': '11',
#   'ftp': '1.000',
#   'orb': '2',
#   'drb': '8',
#   'totrb': '10',
#   'ast': '12',
#   'stl': '2',
#   'blk': '0',
#   'tov': '6',
#   'fouls': '5',
#   'points': '34'},
#  {'game': 27,
#   'data': '1989-05-11',
#   'serie': 'ECS',
#   'team': 'CHI',
#   'opp': 'NYK',
#   'game_number': '2',
#   'result': 'L (-17)',
#   'started': '1',
#   'minutes': '34:00',
#   'fg': '7',
#   'fga': '17',
#   'fgp': '.412',
#   'fg3': '0',
#   'fg3a': '2',
#   'fg3p': '.000',
#   'ft': '1',
#   'fta': '4',
#   'ftp': '.250',
#   'orb': '2',
#   'drb': '6',
#   'totrb': '8',
#   'ast': '3',
#   'stl': '1',
#   'blk': '0',
#   'tov': '1',
#   'fouls': '4',
#   'points': '15'},
#  {'game': 28,
#   'data': '1989-05-13',
#   'serie': 'ECS',
#   'team': 'CHI',
#   'opp': 'NYK',
#   'game_number': '3',
#   'result': 'W (+23)',
#   'started': '1',
#   'minutes': '39:00',
#   'fg': '14',
#   'fga': '25',
#   'fgp': '.560',
#   'fg3': '1',
#   'fg3a': '2',
#   'fg3p': '.500',
#   'ft': '11',
#   'fta': '13',
#   'ftp': '.846',
#   'orb': '2',
#   'drb': '13',
#   'totrb': '15',
#   'ast': '9',
#   'stl': '6',
#   'blk': '1',
#   'tov': '3',
#   'fouls': '3',
#   'points': '40'},
#  {'game': 29,
#   'data': '1989-05-14',
#   'serie': 'ECS',
#   'team': 'CHI',
#   'opp': 'NYK',
#   'game_number': '4',
#   'result': 'W (+13)',
#   'started': '1',
#   'minutes': '42:00',
#   'fg': '12',
#   'fga': '18',
#   'fgp': '.667',
#   'fg3': '0',
#   'fg3a': '1',
#   'fg3p': '.000',
#   'ft': '23',
#   'fta': '28',
#   'ftp': '.821',
#   'orb': '0',
#   'drb': '11',
#   'totrb': '11',
#   'ast': '6',
#   'stl': '1',
#   'blk': '2',
#   'tov': '6',
#   'fouls': '3',
#   'points': '47'},
#  {'game': 30,
#   'data': '1989-05-16',
#   'serie': 'ECS',
#   'team': 'CHI',
#   'opp': 'NYK',
#   'game_number': '5',
#   'result': 'L (-7)',
#   'started': '1',
#   'minutes': '43:00',
#   'fg': '13',
#   'fga': '30',
#   'fgp': '.433',
#   'fg3': '1',
#   'fg3a': '3',
#   'fg3p': '.333',
#   'ft': '11',
#   'fta': '15',
#   'ftp': '.733',
#   'orb': '5',
#   'drb': '3',
#   'totrb': '8',
#   'ast': '10',
#   'stl': '5',
#   'blk': '1',
#   'tov': '3',
#   'fouls': '2',
#   'points': '38'},
#  {'game': 31,
#   'data': '1989-05-19',
#   'serie': 'ECS',
#   'team': 'CHI',
#   'opp': 'NYK',
#   'game_number': '6',
#   'result': 'W (+2)',
#   'started': '1',
#   'minutes': '45:00',
#   'fg': '14',
#   'fga': '22',
#   'fgp': '.636',
#   'fg3': '1',
#   'fg3a': '3',
#   'fg3p': '.333',
#   'ft': '11',
#   'fta': '12',
#   'ftp': '.917',
#   'orb': '1',
#   'drb': '4',
#   'totrb': '5',
#   'ast': '10',
#   'stl': '0',
#   'blk': '4',
#   'tov': '6',
#   'fouls': '3',
#   'points': '40'},
#  {'game': 32,
#   'data': '1989-05-21',
#   'serie': 'ECF',
#   'team': 'CHI',
#   'opp': 'DET',
#   'game_number': '1',
#   'result': 'W (+6)',
#   'started': '1',
#   'minutes': '45:00',
#   'fg': '10',
#   'fga': '29',
#   'fgp': '.345',
#   'fg3': '2',
#   'fg3a': '6',
#   'fg3p': '.333',
#   'ft': '10',
#   'fta': '13',
#   'ftp': '.769',
#   'orb': '2',
#   'drb': '9',
#   'totrb': '11',
#   'ast': '4',
#   'stl': '0',
#   'blk': '0',
#   'tov': '3',
#   'fouls': '5',
#   'points': '32'},
#  {'game': 33,
#   'data': '1989-05-23',
#   'serie': 'ECF',
#   'team': 'CHI',
#   'opp': 'DET',
#   'game_number': '2',
#   'result': 'L (-9)',
#   'started': '1',
#   'minutes': '38:00',
#   'fg': '9',
#   'fga': '20',
#   'fgp': '.450',
#   'fg3': '0',
#   'fg3a': '2',
#   'fg3p': '.000',
#   'ft': '9',
#   'fta': '11',
#   'ftp': '.818',
#   'orb': '1',
#   'drb': '3',
#   'totrb': '4',
#   'ast': '4',
#   'stl': '2',
#   'blk': '1',
#   'tov': '4',
#   'fouls': '5',
#   'points': '27'},
#  {'game': 34,
#   'data': '1989-05-27',
#   'serie': 'ECF',
#   'team': 'CHI',
#   'opp': 'DET',
#   'game_number': '3',
#   'result': 'W (+2)',
#   'started': '1',
#   'minutes': '45:00',
#   'fg': '16',
#   'fga': '26',
#   'fgp': '.615',
#   'fg3': '0',
#   'fg3a': '3',
#   'fg3p': '.000',
#   'ft': '14',
#   'fta': '15',
#   'ftp': '.933',
#   'orb': '3',
#   'drb': '4',
#   'totrb': '7',
#   'ast': '5',
#   'stl': '5',
#   'blk': '0',
#   'tov': '2',
#   'fouls': '2',
#   'points': '46'},
#  {'game': 35,
#   'data': '1989-05-29',
#   'serie': 'ECF',
#   'team': 'CHI',
#   'opp': 'DET',
#   'game_number': '4',
#   'result': 'L (-6)',
#   'started': '1',
#   'minutes': '43:00',
#   'fg': '5',
#   'fga': '15',
#   'fgp': '.333',
#   'fg3': '1',
#   'fg3a': '3',
#   'fg3p': '.333',
#   'ft': '12',
#   'fta': '17',
#   'ftp': '.706',
#   'orb': '0',
#   'drb': '2',
#   'totrb': '2',
#   'ast': '4',
#   'stl': '1',
#   'blk': '0',
#   'tov': '1',
#   'fouls': '5',
#   'points': '23'},
#  {'game': 36,
#   'data': '1989-05-31',
#   'serie': 'ECF',
#   'team': 'CHI',
#   'opp': 'DET',
#   'game_number': '5',
#   'result': 'L (-9)',
#   'started': '1',
#   'minutes': '46:00',
#   'fg': '4',
#   'fga': '8',
#   'fgp': '.500',
#   'fg3': '0',
#   'fg3a': '1',
#   'fg3p': '.000',
#   'ft': '10',
#   'fta': '11',
#   'ftp': '.909',
#   'orb': '0',
#   'drb': '5',
#   'totrb': '5',
#   'ast': '9',
#   'stl': '1',
#   'blk': '0',
#   'tov': '4',
#   'fouls': '3',
#   'points': '18'},
#  {'game': 37,
#   'data': '1989-06-02',
#   'serie': 'ECF',
#   'team': 'CHI',
#   'opp': 'DET',
#   'game_number': '6',
#   'result': 'L (-9)',
#   'started': '1',
#   'minutes': '42:00',
#   'fg': '13',
#   'fga': '26',
#   'fgp': '.500',
#   'fg3': '1',
#   'fg3a': '2',
#   'fg3p': '.500',
#   'ft': '5',
#   'fta': '12',
#   'ftp': '.417',
#   'orb': '0',
#   'drb': '4',
#   'totrb': '4',
#   'ast': '13',
#   'stl': '3',
#   'blk': '2',
#   'tov': '8',
#   'fouls': '5',
#   'points': '32'},
#  {'game': 38,
#   'data': '1990-04-27',
#   'serie': 'EC1',
#   'team': 'CHI',
#   'opp': 'MIL',
#   'game_number': '1',
#   'result': 'W (+14)',
#   'started': '1',
#   'minutes': '44:00',
#   'fg': '15',
#   'fga': '27',
#   'fgp': '.556',
#   'fg3': '0',
#   'fg3a': '1',
#   'fg3p': '.000',
#   'ft': '8',
#   'fta': '11',
#   'ftp': '.727',
#   'orb': '1',
#   'drb': '7',
#   'totrb': '8',
#   'ast': '7',
#   'stl': '2',
#   'blk': '1',
#   'tov': '7',
#   'fouls': '4',
#   'points': '38'},
#  {'game': 39,
#   'data': '1990-04-29',
#   'serie': 'EC1',
#   'team': 'CHI',
#   'opp': 'MIL',
#   'game_number': '2',
#   'result': 'W (+7)',
#   'started': '1',
#   'minutes': '44:00',
#   'fg': '12',
#   'fga': '21',
#   'fgp': '.571',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3p': '',
#   'ft': '12',
#   'fta': '14',
#   'ftp': '.857',
#   'orb': '1',
#   'drb': '8',
#   'totrb': '9',
#   'ast': '11',
#   'stl': '5',
#   'blk': '1',
#   'tov': '5',
#   'fouls': '5',
#   'points': '36'},
#  {'game': 40,
#   'data': '1990-05-01',
#   'serie': 'EC1',
#   'team': 'CHI',
#   'opp': 'MIL',
#   'game_number': '3',
#   'result': 'L (-7)',
#   'started': '1',
#   'minutes': '46:00',
#   'fg': '20',
#   'fga': '35',
#   'fgp': '.571',
#   'fg3': '1',
#   'fg3a': '5',
#   'fg3p': '.200',
#   'ft': '7',
#   'fta': '9',
#   'ftp': '.778',
#   'orb': '2',
#   'drb': '7',
#   'totrb': '9',
#   'ast': '5',
#   'stl': '1',
#   'blk': '2',
#   'tov': '5',
#   'fouls': '4',
#   'points': '48'},
#  {'game': 41,
#   'data': '1990-05-03',
#   'serie': 'EC1',
#   'team': 'CHI',
#   'opp': 'MIL',
#   'game_number': '4',
#   'result': 'W (+24)',
#   'started': '1',
#   'minutes': '32:00',
#   'fg': '8',
#   'fga': '19',
#   'fgp': '.421',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3p': '',
#   'ft': '9',
#   'fta': '13',
#   'ftp': '.692',
#   'orb': '1',
#   'drb': '5',
#   'totrb': '6',
#   'ast': '5',
#   'stl': '2',
#   'blk': '0',
#   'tov': '1',
#   'fouls': '3',
#   'points': '25'},
#  {'game': 42,
#   'data': '1990-05-07',
#   'serie': 'ECS',
#   'team': 'CHI',
#   'opp': 'PHI',
#   'game_number': '1',
#   'result': 'W (+11)',
#   'started': '1',
#   'minutes': '43:00',
#   'fg': '16',
#   'fga': '30',
#   'fgp': '.533',
#   'fg3': '2',
#   'fg3a': '4',
#   'fg3p': '.500',
#   'ft': '5',
#   'fta': '6',
#   'ftp': '.833',
#   'orb': '1',
#   'drb': '4',
#   'totrb': '5',
#   'ast': '6',
#   'stl': '5',
#   'blk': '2',
#   'tov': '4',
#   'fouls': '3',
#   'points': '39'},
#  {'game': 43,
#   'data': '1990-05-09',
#   'serie': 'ECS',
#   'team': 'CHI',
#   'opp': 'PHI',
#   'game_number': '2',
#   'result': 'W (+5)',
#   'started': '1',
#   'minutes': '43:00',
#   'fg': '18',
#   'fga': '36',
#   'fgp': '.500',
#   'fg3': '1',
#   'fg3a': '3',
#   'fg3p': '.333',
#   'ft': '8',
#   'fta': '8',
#   'ftp': '1.000',
#   'orb': '4',
#   'drb': '4',
#   'totrb': '8',
#   'ast': '7',
#   'stl': '3',
#   'blk': '0',
#   'tov': '2',
#   'fouls': '3',
#   'points': '45'},
#  {'game': 44,
#   'data': '1990-05-11',
#   'serie': 'ECS',
#   'team': 'CHI',
#   'opp': 'PHI',
#   'game_number': '3',
#   'result': 'L (-6)',
#   'started': '1',
#   'minutes': '42:00',
#   'fg': '19',
#   'fga': '34',
#   'fgp': '.559',
#   'fg3': '4',
#   'fg3a': '11',
#   'fg3p': '.364',
#   'ft': '7',
#   'fta': '9',
#   'ftp': '.778',
#   'orb': '2',
#   'drb': '3',
#   'totrb': '5',
#   'ast': '5',
#   'stl': '4',
#   'blk': '1',
#   'tov': '5',
#   'fouls': '4',
#   'points': '49'},
#  {'game': 45,
#   'data': '1990-05-13',
#   'serie': 'ECS',
#   'team': 'CHI',
#   'opp': 'PHI',
#   'game_number': '4',
#   'result': 'W (+10)',
#   'started': '1',
#   'minutes': '42:00',
#   'fg': '16',
#   'fga': '31',
#   'fgp': '.516',
#   'fg3': '1',
#   'fg3a': '2',
#   'fg3p': '.500',
#   'ft': '12',
#   'fta': '13',
#   'ftp': '.923',
#   'orb': '1',
#   'drb': '5',
#   'totrb': '6',
#   'ast': '11',
#   'stl': '2',
#   'blk': '2',
#   'tov': '3',
#   'fouls': '3',
#   'points': '45'},
#  {'game': 46,
#   'data': '1990-05-16',
#   'serie': 'ECS',
#   'team': 'CHI',
#   'opp': 'PHI',
#   'game_number': '5',
#   'result': 'W (+18)',
#   'started': '1',
#   'minutes': '42:00',
#   'fg': '17',
#   'fga': '26',
#   'fgp': '.654',
#   'fg3': '1',
#   'fg3a': '3',
#   'fg3p': '.333',
#   'ft': '2',
#   'fta': '4',
#   'ftp': '.500',
#   'orb': '2',
#   'drb': '7',
#   'totrb': '9',
#   'ast': '8',
#   'stl': '6',
#   'blk': '1',
#   'tov': '4',
#   'fouls': '2',
#   'points': '37'},
#  {'game': 47,
#   'data': '1990-05-20',
#   'serie': 'ECF',
#   'team': 'CHI',
#   'opp': 'DET',
#   'game_number': '1',
#   'result': 'L (-9)',
#   'started': '1',
#   'minutes': '42:00',
#   'fg': '12',
#   'fga': '27',
#   'fgp': '.444',
#   'fg3': '2',
#   'fg3a': '6',
#   'fg3p': '.333',
#   'ft': '8',
#   'fta': '8',
#   'ftp': '1.000',
#   'orb': '1',
#   'drb': '6',
#   'totrb': '7',
#   'ast': '5',
#   'stl': '3',
#   'blk': '0',
#   'tov': '1',
#   'fouls': '3',
#   'points': '34'},
#  {'game': 48,
#   'data': '1990-05-22',
#   'serie': 'ECF',
#   'team': 'CHI',
#   'opp': 'DET',
#   'game_number': '2',
#   'result': 'L (-9)',
#   'started': '1',
#   'minutes': '45:00',
#   'fg': '5',
#   'fga': '16',
#   'fgp': '.313',
#   'fg3': '0',
#   'fg3a': '2',
#   'fg3p': '.000',
#   'ft': '10',
#   'fta': '12',
#   'ftp': '.833',
#   'orb': '1',
#   'drb': '6',
#   'totrb': '7',
#   'ast': '7',
#   'stl': '4',
#   'blk': '1',
#   'tov': '3',
#   'fouls': '5',
#   'points': '20'},
#  {'game': 49,
#   'data': '1990-05-26',
#   'serie': 'ECF',
#   'team': 'CHI',
#   'opp': 'DET',
#   'game_number': '3',
#   'result': 'W (+5)',
#   'started': '1',
#   'minutes': '43:00',
#   'fg': '17',
#   'fga': '32',
#   'fgp': '.531',
#   'fg3': '2',
#   'fg3a': '2',
#   'fg3p': '1.000',
#   'ft': '11',
#   'fta': '13',
#   'ftp': '.846',
#   'orb': '3',
#   'drb': '7',
#   'totrb': '10',
#   'ast': '4',
#   'stl': '1',
#   'blk': '0',
#   'tov': '4',
#   'fouls': '3',
#   'points': '47'},
#  {'game': 50,
#   'data': '1990-05-28',
#   'serie': 'ECF',
#   'team': 'CHI',
#   'opp': 'DET',
#   'game_number': '4',
#   'result': 'W (+7)',
#   'started': '1',
#   'minutes': '43:00',
#   'fg': '13',
#   'fga': '26',
#   'fgp': '.500',
#   'fg3': '0',
#   'fg3a': '1',
#   'fg3p': '.000',
#   'ft': '16',
#   'fta': '19',
#   'ftp': '.842',
#   'orb': '0',
#   'drb': '4',
#   'totrb': '4',
#   'ast': '9',
#   'stl': '4',
#   'blk': '3',
#   'tov': '4',
#   'fouls': '5',
#   'points': '42'},
#  {'game': 51,
#   'data': '1990-05-30',
#   'serie': 'ECF',
#   'team': 'CHI',
#   'opp': 'DET',
#   'game_number': '5',
#   'result': 'L (-14)',
#   'started': '1',
#   'minutes': '39:00',
#   'fg': '7',
#   'fga': '19',
#   'fgp': '.368',
#   'fg3': '1',
#   'fg3a': '4',
#   'fg3p': '.250',
#   'ft': '7',
#   'fta': '9',
#   'ftp': '.778',
#   'orb': '1',
#   'drb': '3',
#   'totrb': '4',
#   'ast': '8',
#   'stl': '1',
#   'blk': '0',
#   'tov': '1',
#   'fouls': '1',
#   'points': '22'},
#  {'game': 52,
#   'data': '1990-06-01',
#   'serie': 'ECF',
#   'team': 'CHI',
#   'opp': 'DET',
#   'game_number': '6',
#   'result': 'W (+18)',
#   'started': '1',
#   'minutes': '39:00',
#   'fg': '11',
#   'fga': '20',
#   'fgp': '.550',
#   'fg3': '1',
#   'fg3a': '4',
#   'fg3p': '.250',
#   'ft': '6',
#   'fta': '6',
#   'ftp': '1.000',
#   'orb': '1',
#   'drb': '9',
#   'totrb': '10',
#   'ast': '2',
#   'stl': '1',
#   'blk': '0',
#   'tov': '3',
#   'fouls': '4',
#   'points': '29'},
#  {'game': 53,
#   'data': '1990-06-03',
#   'serie': 'ECF',
#   'team': 'CHI',
#   'opp': 'DET',
#   'game_number': '7',
#   'result': 'L (-19)',
#   'started': '1',
#   'minutes': '45:00',
#   'fg': '13',
#   'fga': '27',
#   'fgp': '.481',
#   'fg3': '0',
#   'fg3a': '2',
#   'fg3p': '.000',
#   'ft': '5',
#   'fta': '5',
#   'ftp': '1.000',
#   'orb': '2',
#   'drb': '6',
#   'totrb': '8',
#   'ast': '9',
#   'stl': '1',
#   'blk': '0',
#   'tov': '4',
#   'fouls': '2',
#   'points': '31'},
#  {'game': 54,
#   'data': '1991-04-25',
#   'serie': 'EC1',
#   'team': 'CHI',
#   'opp': 'NYK',
#   'game_number': '1',
#   'result': 'W (+41)',
#   'started': '1',
#   'minutes': '32:00',
#   'fg': '8',
#   'fga': '15',
#   'fgp': '.533',
#   'fg3': '3',
#   'fg3a': '4',
#   'fg3p': '.750',
#   'ft': '9',
#   'fta': '9',
#   'ftp': '1.000',
#   'orb': '1',
#   'drb': '5',
#   'totrb': '6',
#   'ast': '6',
#   'stl': '2',
#   'blk': '0',
#   'tov': '1',
#   'fouls': '2',
#   'points': '28'},
#  {'game': 55,
#   'data': '1991-04-28',
#   'serie': 'EC1',
#   'team': 'CHI',
#   'opp': 'NYK',
#   'game_number': '2',
#   'result': 'W (+10)',
#   'started': '1',
#   'minutes': '42:00',
#   'fg': '9',
#   'fga': '16',
#   'fgp': '.563',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3p': '',
#   'ft': '8',
#   'fta': '9',
#   'ftp': '.889',
#   'orb': '1',
#   'drb': '4',
#   'totrb': '5',
#   'ast': '5',
#   'stl': '0',
#   'blk': '1',
#   'tov': '2',
#   'fouls': '2',
#   'points': '26'},
#  {'game': 56,
#   'data': '1991-04-30',
#   'serie': 'EC1',
#   'team': 'CHI',
#   'opp': 'NYK',
#   'game_number': '3',
#   'result': 'W (+9)',
#   'started': '1',
#   'minutes': '39:00',
#   'fg': '14',
#   'fga': '28',
#   'fgp': '.500',
#   'fg3': '0',
#   'fg3a': '2',
#   'fg3p': '.000',
#   'ft': '5',
#   'fta': '5',
#   'ftp': '1.000',
#   'orb': '1',
#   'drb': '2',
#   'totrb': '3',
#   'ast': '7',
#   'stl': '6',
#   'blk': '1',
#   'tov': '1',
#   'fouls': '3',
#   'points': '33'},
#  {'game': 57,
#   'data': '1991-05-04',
#   'serie': 'ECS',
#   'team': 'CHI',
#   'opp': 'PHI',
#   'game_number': '1',
#   'result': 'W (+13)',
#   'started': '1',
#   'minutes': '31:00',
#   'fg': '8',
#   'fga': '15',
#   'fgp': '.533',
#   'fg3': '0',
#   'fg3a': '1',
#   'fg3p': '.000',
#   'ft': '13',
#   'fta': '15',
#   'ftp': '.867',
#   'orb': '0',
#   'drb': '5',
#   'totrb': '5',
#   'ast': '5',
#   'stl': '3',
#   'blk': '1',
#   'tov': '1',
#   'fouls': '2',
#   'points': '29'},
#  {'game': 58,
#   'data': '1991-05-06',
#   'serie': 'ECS',
#   'team': 'CHI',
#   'opp': 'PHI',
#   'game_number': '2',
#   'result': 'W (+12)',
#   'started': '1',
#   'minutes': '40:00',
#   'fg': '12',
#   'fga': '26',
#   'fgp': '.462',
#   'fg3': '0',
#   'fg3a': '5',
#   'fg3p': '.000',
#   'ft': '5',
#   'fta': '7',
#   'ftp': '.714',
#   'orb': '1',
#   'drb': '7',
#   'totrb': '8',
#   'ast': '9',
#   'stl': '1',
#   'blk': '1',
#   'tov': '1',
#   'fouls': '4',
#   'points': '29'},
#  {'game': 59,
#   'data': '1991-05-10',
#   'serie': 'ECS',
#   'team': 'CHI',
#   'opp': 'PHI',
#   'game_number': '3',
#   'result': 'L (-2)',
#   'started': '1',
#   'minutes': '42:00',
#   'fg': '20',
#   'fga': '34',
#   'fgp': '.588',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3p': '',
#   'ft': '6',
#   'fta': '9',
#   'ftp': '.667',
#   'orb': '0',
#   'drb': '4',
#   'totrb': '4',
#   'ast': '6',
#   'stl': '1',
#   'blk': '4',
#   'tov': '2',
#   'fouls': '3',
#   'points': '46'},
#  {'game': 60,
#   'data': '1991-05-12',
#   'serie': 'ECS',
#   'team': 'CHI',
#   'opp': 'PHI',
#   'game_number': '4',
#   'result': 'W (+16)',
#   'started': '1',
#   'minutes': '41:00',
#   'fg': '11',
#   'fga': '27',
#   'fgp': '.407',
#   'fg3': '2',
#   'fg3a': '3',
#   'fg3p': '.667',
#   'ft': '1',
#   'fta': '2',
#   'ftp': '.500',
#   'orb': '0',
#   'drb': '4',
#   'totrb': '4',
#   'ast': '12',
#   'stl': '4',
#   'blk': '0',
#   'tov': '1',
#   'fouls': '4',
#   'points': '25'},
#  {'game': 61,
#   'data': '1991-05-14',
#   'serie': 'ECS',
#   'team': 'CHI',
#   'opp': 'PHI',
#   'game_number': '5',
#   'result': 'W (+5)',
#   'started': '1',
#   'minutes': '42:00',
#   'fg': '14',
#   'fga': '31',
#   'fgp': '.452',
#   'fg3': '0',
#   'fg3a': '2',
#   'fg3p': '.000',
#   'ft': '10',
#   'fta': '11',
#   'ftp': '.909',
#   'orb': '4',
#   'drb': '15',
#   'totrb': '19',
#   'ast': '7',
#   'stl': '0',
#   'blk': '1',
#   'tov': '4',
#   'fouls': '3',
#   'points': '38'},
#  {'game': 62,
#   'data': '1991-05-19',
#   'serie': 'ECF',
#   'team': 'CHI',
#   'opp': 'DET',
#   'game_number': '1',
#   'result': 'W (+11)',
#   'started': '1',
#   'minutes': '38:00',
#   'fg': '6',
#   'fga': '15',
#   'fgp': '.400',
#   'fg3': '0',
#   'fg3a': '1',
#   'fg3p': '.000',
#   'ft': '10',
#   'fta': '13',
#   'ftp': '.769',
#   'orb': '0',
#   'drb': '3',
#   'totrb': '3',
#   'ast': '6',
#   'stl': '3',
#   'blk': '0',
#   'tov': '6',
#   'fouls': '4',
#   'points': '22'},
#  {'game': 63,
#   'data': '1991-05-21',
#   'serie': 'ECF',
#   'team': 'CHI',
#   'opp': 'DET',
#   'game_number': '2',
#   'result': 'W (+8)',
#   'started': '1',
#   'minutes': '39:00',
#   'fg': '10',
#   'fga': '20',
#   'fgp': '.500',
#   'fg3': '2',
#   'fg3a': '2',
#   'fg3p': '1.000',
#   'ft': '13',
#   'fta': '14',
#   'ftp': '.929',
#   'orb': '2',
#   'drb': '1',
#   'totrb': '3',
#   'ast': '7',
#   'stl': '2',
#   'blk': '0',
#   'tov': '3',
#   'fouls': '2',
#   'points': '35'},
#  {'game': 64,
#   'data': '1991-05-25',
#   'serie': 'ECF',
#   'team': 'CHI',
#   'opp': 'DET',
#   'game_number': '3',
#   'result': 'W (+6)',
#   'started': '1',
#   'minutes': '46:00',
#   'fg': '11',
#   'fga': '19',
#   'fgp': '.579',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3p': '',
#   'ft': '11',
#   'fta': '12',
#   'ftp': '.917',
#   'orb': '0',
#   'drb': '7',
#   'totrb': '7',
#   'ast': '7',
#   'stl': '3',
#   'blk': '5',
#   'tov': '1',
#   'fouls': '4',
#   'points': '33'},
#  {'game': 65,
#   'data': '1991-05-27',
#   'serie': 'ECF',
#   'team': 'CHI',
#   'opp': 'DET',
#   'game_number': '4',
#   'result': 'W (+21)',
#   'started': '1',
#   'minutes': '37:00',
#   'fg': '11',
#   'fga': '17',
#   'fgp': '.647',
#   'fg3': '1',
#   'fg3a': '2',
#   'fg3p': '.500',
#   'ft': '6',
#   'fta': '9',
#   'ftp': '.667',
#   'orb': '0',
#   'drb': '8',
#   'totrb': '8',
#   'ast': '8',
#   'stl': '1',
#   'blk': '2',
#   'tov': '2',
#   'fouls': '2',
#   'points': '29'},
#  {'game': 66,
#   'data': '1991-06-02',
#   'serie': 'FIN',
#   'team': 'CHI',
#   'opp': 'LAL',
#   'game_number': '1',
#   'result': 'L (-2)',
#   'started': '1',
#   'minutes': '40:00',
#   'fg': '14',
#   'fga': '24',
#   'fgp': '.583',
#   'fg3': '1',
#   'fg3a': '1',
#   'fg3p': '1.000',
#   'ft': '7',
#   'fta': '9',
#   'ftp': '.778',
#   'orb': '2',
#   'drb': '6',
#   'totrb': '8',
#   'ast': '12',
#   'stl': '3',
#   'blk': '0',
#   'tov': '4',
#   'fouls': '5',
#   'points': '36'},
#  {'game': 67,
#   'data': '1991-06-05',
#   'serie': 'FIN',
#   'team': 'CHI',
#   'opp': 'LAL',
#   'game_number': '2',
#   'result': 'W (+21)',
#   'started': '1',
#   'minutes': '36:00',
#   'fg': '15',
#   'fga': '18',
#   'fgp': '.833',
#   'fg3': '0',
#   'fg3a': '1',
#   'fg3p': '.000',
#   'ft': '3',
#   'fta': '4',
#   'ftp': '.750',
#   'orb': '1',
#   'drb': '6',
#   'totrb': '7',
#   'ast': '13',
#   'stl': '2',
#   'blk': '1',
#   'tov': '4',
#   'fouls': '4',
#   'points': '33'},
#  {'game': 68,
#   'data': '1991-06-07',
#   'serie': 'FIN',
#   'team': 'CHI',
#   'opp': 'LAL',
#   'game_number': '3',
#   'result': 'W (+8)',
#   'started': '1',
#   'minutes': '52:00',
#   'fg': '11',
#   'fga': '28',
#   'fgp': '.393',
#   'fg3': '1',
#   'fg3a': '1',
#   'fg3p': '1.000',
#   'ft': '6',
#   'fta': '6',
#   'ftp': '1.000',
#   'orb': '4',
#   'drb': '5',
#   'totrb': '9',
#   'ast': '9',
#   'stl': '4',
#   'blk': '2',
#   'tov': '3',
#   'fouls': '5',
#   'points': '29'},
#  {'game': 69,
#   'data': '1991-06-09',
#   'serie': 'FIN',
#   'team': 'CHI',
#   'opp': 'LAL',
#   'game_number': '4',
#   'result': 'W (+15)',
#   'started': '1',
#   'minutes': '44:00',
#   'fg': '11',
#   'fga': '20',
#   'fgp': '.550',
#   'fg3': '0',
#   'fg3a': '1',
#   'fg3p': '.000',
#   'ft': '6',
#   'fta': '6',
#   'ftp': '1.000',
#   'orb': '1',
#   'drb': '4',
#   'totrb': '5',
#   'ast': '13',
#   'stl': '0',
#   'blk': '2',
#   'tov': '1',
#   'fouls': '3',
#   'points': '28'},
#  {'game': 70,
#   'data': '1991-06-12',
#   'serie': 'FIN',
#   'team': 'CHI',
#   'opp': 'LAL',
#   'game_number': '5',
#   'result': 'W (+7)',
#   'started': '1',
#   'minutes': '48:00',
#   'fg': '12',
#   'fga': '23',
#   'fgp': '.522',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3p': '',
#   'ft': '6',
#   'fta': '8',
#   'ftp': '.750',
#   'orb': '0',
#   'drb': '4',
#   'totrb': '4',
#   'ast': '10',
#   'stl': '5',
#   'blk': '2',
#   'tov': '6',
#   'fouls': '1',
#   'points': '30'},
#  {'game': 71,
#   'data': '1992-04-24',
#   'serie': 'EC1',
#   'team': 'CHI',
#   'opp': 'MIA',
#   'game_number': '1',
#   'result': 'W (+19)',
#   'started': '1',
#   'minutes': '41:00',
#   'fg': '21',
#   'fga': '34',
#   'fgp': '.618',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3p': '',
#   'ft': '4',
#   'fta': '4',
#   'ftp': '1.000',
#   'orb': '1',
#   'drb': '10',
#   'totrb': '11',
#   'ast': '9',
#   'stl': '3',
#   'blk': '1',
#   'tov': '5',
#   'fouls': '4',
#   'points': '46'},
#  {'game': 72,
#   'data': '1992-04-26',
#   'serie': 'EC1',
#   'team': 'CHI',
#   'opp': 'MIA',
#   'game_number': '2',
#   'result': 'W (+30)',
#   'started': '1',
#   'minutes': '35:00',
#   'fg': '12',
#   'fga': '23',
#   'fgp': '.522',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3p': '',
#   'ft': '9',
#   'fta': '10',
#   'ftp': '.900',
#   'orb': '4',
#   'drb': '9',
#   'totrb': '13',
#   'ast': '6',
#   'stl': '2',
#   'blk': '0',
#   'tov': '4',
#   'fouls': '3',
#   'points': '33'},
#  {'game': 73,
#   'data': '1992-04-29',
#   'serie': 'EC1',
#   'team': 'CHI',
#   'opp': 'MIA',
#   'game_number': '3',
#   'result': 'W (+5)',
#   'started': '1',
#   'minutes': '43:00',
#   'fg': '20',
#   'fga': '30',
#   'fgp': '.667',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3p': '',
#   'ft': '16',
#   'fta': '18',
#   'ftp': '.889',
#   'orb': '1',
#   'drb': '4',
#   'totrb': '5',
#   'ast': '5',
#   'stl': '4',
#   'blk': '2',
#   'tov': '2',
#   'fouls': '3',
#   'points': '56'},
#  {'game': 74,
#   'data': '1992-05-05',
#   'serie': 'ECS',
#   'team': 'CHI',
#   'opp': 'NYK',
#   'game_number': '1',
#   'result': 'L (-5)',
#   'started': '1',
#   'minutes': '44:00',
#   'fg': '12',
#   'fga': '23',
#   'fgp': '.522',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3p': '',
#   'ft': '7',
#   'fta': '8',
#   'ftp': '.875',
#   'orb': '1',
#   'drb': '5',
#   'totrb': '6',
#   'ast': '3',
#   'stl': '1',
#   'blk': '3',
#   'tov': '2',
#   'fouls': '4',
#   'points': '31'},
#  {'game': 75,
#   'data': '1992-05-07',
#   'serie': 'ECS',
#   'team': 'CHI',
#   'opp': 'NYK',
#   'game_number': '2',
#   'result': 'W (+8)',
#   'started': '1',
#   'minutes': '43:00',
#   'fg': '12',
#   'fga': '24',
#   'fgp': '.500',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3p': '',
#   'ft': '3',
#   'fta': '8',
#   'ftp': '.375',
#   'orb': '1',
#   'drb': '5',
#   'totrb': '6',
#   'ast': '5',
#   'stl': '3',
#   'blk': '0',
#   'tov': '2',
#   'fouls': '2',
#   'points': '27'},
#  {'game': 76,
#   'data': '1992-05-09',
#   'serie': 'ECS',
#   'team': 'CHI',
#   'opp': 'NYK',
#   'game_number': '3',
#   'result': 'W (+8)',
#   'started': '1',
#   'minutes': '44:00',
#   'fg': '12',
#   'fga': '24',
#   'fgp': '.500',
#   'fg3': '1',
#   'fg3a': '3',
#   'fg3p': '.333',
#   'ft': '7',
#   'fta': '10',
#   'ftp': '.700',
#   'orb': '1',
#   'drb': '8',
#   'totrb': '9',
#   'ast': '3',
#   'stl': '3',
#   'blk': '1',
#   'tov': '6',
#   'fouls': '2',
#   'points': '32'},
#  {'game': 77,
#   'data': '1992-05-10',
#   'serie': 'ECS',
#   'team': 'CHI',
#   'opp': 'NYK',
#   'game_number': '4',
#   'result': 'L (-7)',
#   'started': '1',
#   'minutes': '44:00',
#   'fg': '12',
#   'fga': '26',
#   'fgp': '.462',
#   'fg3': '0',
#   'fg3a': '2',
#   'fg3p': '.000',
#   'ft': '5',
#   'fta': '6',
#   'ftp': '.833',
#   'orb': '2',
#   'drb': '2',
#   'totrb': '4',
#   'ast': '4',
#   'stl': '0',
#   'blk': '0',
#   'tov': '0',
#   'fouls': '1',
#   'points': '29'},
#  {'game': 78,
#   'data': '1992-05-12',
#   'serie': 'ECS',
#   'team': 'CHI',
#   'opp': 'NYK',
#   'game_number': '5',
#   'result': 'W (+8)',
#   'started': '1',
#   'minutes': '40:00',
#   'fg': '11',
#   'fga': '23',
#   'fgp': '.478',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3p': '',
#   'ft': '15',
#   'fta': '17',
#   'ftp': '.882',
#   'orb': '2',
#   'drb': '3',
#   'totrb': '5',
#   'ast': '3',
#   'stl': '1',
#   'blk': '0',
#   'tov': '4',
#   'fouls': '3',
#   'points': '37'},
#  {'game': 79,
#   'data': '1992-05-14',
#   'serie': 'ECS',
#   'team': 'CHI',
#   'opp': 'NYK',
#   'game_number': '6',
#   'result': 'L (-14)',
#   'started': '1',
#   'minutes': '45:00',
#   'fg': '9',
#   'fga': '25',
#   'fgp': '.360',
#   'fg3': '1',
#   'fg3a': '5',
#   'fg3p': '.200',
#   'ft': '2',
#   'fta': '4',
#   'ftp': '.500',
#   'orb': '0',
#   'drb': '4',
#   'totrb': '4',
#   'ast': '8',
#   'stl': '0',
#   'blk': '1',
#   'tov': '7',
#   'fouls': '0',
#   'points': '21'},
#  {'game': 80,
#   'data': '1992-05-17',
#   'serie': 'ECS',
#   'team': 'CHI',
#   'opp': 'NYK',
#   'game_number': '7',
#   'result': 'W (+29)',
#   'started': '1',
#   'minutes': '42:00',
#   'fg': '15',
#   'fga': '29',
#   'fgp': '.517',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3p': '',
#   'ft': '12',
#   'fta': '13',
#   'ftp': '.923',
#   'orb': '3',
#   'drb': '3',
#   'totrb': '6',
#   'ast': '4',
#   'stl': '2',
#   'blk': '3',
#   'tov': '5',
#   'fouls': '3',
#   'points': '42'},
#  {'game': 81,
#   'data': '1992-05-19',
#   'serie': 'ECF',
#   'team': 'CHI',
#   'opp': 'CLE',
#   'game_number': '1',
#   'result': 'W (+14)',
#   'started': '1',
#   'minutes': '40:00',
#   'fg': '15',
#   'fga': '29',
#   'fgp': '.517',
#   'fg3': '1',
#   'fg3a': '2',
#   'fg3p': '.500',
#   'ft': '2',
#   'fta': '2',
#   'ftp': '1.000',
#   'orb': '1',
#   'drb': '5',
#   'totrb': '6',
#   'ast': '7',
#   'stl': '2',
#   'blk': '1',
#   'tov': '1',
#   'fouls': '0',
#   'points': '33'},
#  {'game': 82,
#   'data': '1992-05-21',
#   'serie': 'ECF',
#   'team': 'CHI',
#   'opp': 'CLE',
#   'game_number': '2',
#   'result': 'L (-26)',
#   'started': '1',
#   'minutes': '35:00',
#   'fg': '7',
#   'fga': '22',
#   'fgp': '.318',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3p': '',
#   'ft': '6',
#   'fta': '7',
#   'ftp': '.857',
#   'orb': '8',
#   'drb': '3',
#   'totrb': '11',
#   'ast': '3',
#   'stl': '3',
#   'blk': '2',
#   'tov': '6',
#   'fouls': '3',
#   'points': '20'},
#  {'game': 83,
#   'data': '1992-05-23',
#   'serie': 'ECF',
#   'team': 'CHI',
#   'opp': 'CLE',
#   'game_number': '3',
#   'result': 'W (+9)',
#   'started': '1',
#   'minutes': '43:00',
#   'fg': '13',
#   'fga': '27',
#   'fgp': '.481',
#   'fg3': '1',
#   'fg3a': '1',
#   'fg3p': '1.000',
#   'ft': '9',
#   'fta': '10',
#   'ftp': '.900',
#   'orb': '3',
#   'drb': '3',
#   'totrb': '6',
#   'ast': '9',
#   'stl': '1',
#   'blk': '0',
#   'tov': '5',
#   'fouls': '3',
#   'points': '36'},
#  {'game': 84,
#   'data': '1992-05-25',
#   'serie': 'ECF',
#   'team': 'CHI',
#   'opp': 'CLE',
#   'game_number': '4',
#   'result': 'L (-14)',
#   'started': '1',
#   'minutes': '44:00',
#   'fg': '15',
#   'fga': '33',
#   'fgp': '.455',
#   'fg3': '1',
#   'fg3a': '3',
#   'fg3p': '.333',
#   'ft': '4',
#   'fta': '5',
#   'ftp': '.800',
#   'orb': '2',
#   'drb': '3',
#   'totrb': '5',
#   'ast': '6',
#   'stl': '3',
#   'blk': '0',
#   'tov': '5',
#   'fouls': '3',
#   'points': '35'},
#  {'game': 85,
#   'data': '1992-05-27',
#   'serie': 'ECF',
#   'team': 'CHI',
#   'opp': 'CLE',
#   'game_number': '5',
#   'result': 'W (+23)',
#   'started': '1',
#   'minutes': '39:00',
#   'fg': '13',
#   'fga': '28',
#   'fgp': '.464',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3p': '',
#   'ft': '11',
#   'fta': '12',
#   'ftp': '.917',
#   'orb': '0',
#   'drb': '3',
#   'totrb': '3',
#   'ast': '5',
#   'stl': '4',
#   'blk': '0',
#   'tov': '0',
#   'fouls': '4',
#   'points': '37'},
#  {'game': 86,
#   'data': '1992-05-29',
#   'serie': 'ECF',
#   'team': 'CHI',
#   'opp': 'CLE',
#   'game_number': '6',
#   'result': 'W (+5)',
#   'started': '1',
#   'minutes': '44:00',
#   'fg': '10',
#   'fga': '27',
#   'fgp': '.370',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3p': '',
#   'ft': '9',
#   'fta': '9',
#   'ftp': '1.000',
#   'orb': '1',
#   'drb': '7',
#   'totrb': '8',
#   'ast': '8',
#   'stl': '2',
#   'blk': '0',
#   'tov': '3',
#   'fouls': '3',
#   'points': '29'},
#  {'game': 87,
#   'data': '1992-06-03',
#   'serie': 'FIN',
#   'team': 'CHI',
#   'opp': 'POR',
#   'game_number': '1',
#   'result': 'W (+33)',
#   'started': '1',
#   'minutes': '34:00',
#   'fg': '16',
#   'fga': '27',
#   'fgp': '.593',
#   'fg3': '6',
#   'fg3a': '10',
#   'fg3p': '.600',
#   'ft': '1',
#   'fta': '1',
#   'ftp': '1.000',
#   'orb': '2',
#   'drb': '1',
#   'totrb': '3',
#   'ast': '11',
#   'stl': '2',
#   'blk': '0',
#   'tov': '1',
#   'fouls': '0',
#   'points': '39'},
#  {'game': 88,
#   'data': '1992-06-05',
#   'serie': 'FIN',
#   'team': 'CHI',
#   'opp': 'POR',
#   'game_number': '2',
#   'result': 'L (-11)',
#   'started': '1',
#   'minutes': '50:00',
#   'fg': '16',
#   'fga': '32',
#   'fgp': '.500',
#   'fg3': '0',
#   'fg3a': '4',
#   'fg3p': '.000',
#   'ft': '7',
#   'fta': '9',
#   'ftp': '.778',
#   'orb': '1',
#   'drb': '4',
#   'totrb': '5',
#   'ast': '10',
#   'stl': '1',
#   'blk': '0',
#   'tov': '5',
#   'fouls': '5',
#   'points': '39'},
#  {'game': 89,
#   'data': '1992-06-07',
#   'serie': 'FIN',
#   'team': 'CHI',
#   'opp': 'POR',
#   'game_number': '3',
#   'result': 'W (+10)',
#   'started': '1',
#   'minutes': '41:00',
#   'fg': '11',
#   'fga': '22',
#   'fgp': '.500',
#   'fg3': '0',
#   'fg3a': '1',
#   'fg3p': '.000',
#   'ft': '4',
#   'fta': '4',
#   'ftp': '1.000',
#   'orb': '2',
#   'drb': '5',
#   'totrb': '7',
#   'ast': '4',
#   'stl': '3',
#   'blk': '0',
#   'tov': '5',
#   'fouls': '4',
#   'points': '26'},
#  {'game': 90,
#   'data': '1992-06-10',
#   'serie': 'FIN',
#   'team': 'CHI',
#   'opp': 'POR',
#   'game_number': '4',
#   'result': 'L (-5)',
#   'started': '1',
#   'minutes': '44:00',
#   'fg': '11',
#   'fga': '26',
#   'fgp': '.423',
#   'fg3': '2',
#   'fg3a': '6',
#   'fg3p': '.333',
#   'ft': '8',
#   'fta': '8',
#   'ftp': '1.000',
#   'orb': '0',
#   'drb': '5',
#   'totrb': '5',
#   'ast': '6',
#   'stl': '0',
#   'blk': '0',
#   'tov': '5',
#   'fouls': '4',
#   'points': '32'},
#  {'game': 91,
#   'data': '1992-06-12',
#   'serie': 'FIN',
#   'team': 'CHI',
#   'opp': 'POR',
#   'game_number': '5',
#   'result': 'W (+13)',
#   'started': '1',
#   'minutes': '42:00',
#   'fg': '14',
#   'fga': '23',
#   'fgp': '.609',
#   'fg3': '2',
#   'fg3a': '4',
#   'fg3p': '.500',
#   'ft': '16',
#   'fta': '19',
#   'ftp': '.842',
#   'orb': '0',
#   'drb': '5',
#   'totrb': '5',
#   'ast': '4',
#   'stl': '0',
#   'blk': '1',
#   'tov': '4',
#   'fouls': '5',
#   'points': '46'},
#  {'game': 92,
#   'data': '1992-06-14',
#   'serie': 'FIN',
#   'team': 'CHI',
#   'opp': 'POR',
#   'game_number': '6',
#   'result': 'W (+4)',
#   'started': '1',
#   'minutes': '43:00',
#   'fg': '13',
#   'fga': '24',
#   'fgp': '.542',
#   'fg3': '2',
#   'fg3a': '3',
#   'fg3p': '.667',
#   'ft': '5',
#   'fta': '5',
#   'ftp': '1.000',
#   'orb': '1',
#   'drb': '3',
#   'totrb': '4',
#   'ast': '4',
#   'stl': '4',
#   'blk': '1',
#   'tov': '4',
#   'fouls': '3',
#   'points': '33'},
#  {'game': 93,
#   'data': '1993-04-30',
#   'serie': 'EC1',
#   'team': 'CHI',
#   'opp': 'ATL',
#   'game_number': '1',
#   'result': 'W (+24)',
#   'started': '1',
#   'minutes': '29:00',
#   'fg': '15',
#   'fga': '26',
#   'fgp': '.577',
#   'fg3': '2',
#   'fg3a': '4',
#   'fg3p': '.500',
#   'ft': '3',
#   'fta': '4',
#   'ftp': '.750',
#   'orb': '3',
#   'drb': '4',
#   'totrb': '7',
#   'ast': '5',
#   'stl': '0',
#   'blk': '0',
#   'tov': '0',
#   'fouls': '3',
#   'points': '35'},
#  {'game': 94,
#   'data': '1993-05-02',
#   'serie': 'EC1',
#   'team': 'CHI',
#   'opp': 'ATL',
#   'game_number': '2',
#   'result': 'W (+15)',
#   'started': '1',
#   'minutes': '38:00',
#   'fg': '10',
#   'fga': '24',
#   'fgp': '.417',
#   'fg3': '2',
#   'fg3a': '4',
#   'fg3p': '.500',
#   'ft': '7',
#   'fta': '8',
#   'ftp': '.875',
#   'orb': '0',
#   'drb': '6',
#   'totrb': '6',
#   'ast': '4',
#   'stl': '3',
#   'blk': '4',
#   'tov': '0',
#   'fouls': '5',
#   'points': '29'},
#  {'game': 95,
#   'data': '1993-05-04',
#   'serie': 'EC1',
#   'team': 'CHI',
#   'opp': 'ATL',
#   'game_number': '3',
#   'result': 'W (+10)',
#   'started': '1',
#   'minutes': '40:00',
#   'fg': '16',
#   'fga': '28',
#   'fgp': '.571',
#   'fg3': '2',
#   'fg3a': '5',
#   'fg3p': '.400',
#   'ft': '5',
#   'fta': '5',
#   'ftp': '1.000',
#   'orb': '0',
#   'drb': '7',
#   'totrb': '7',
#   'ast': '4',
#   'stl': '2',
#   'blk': '1',
#   'tov': '4',
#   'fouls': '4',
#   'points': '39'},
#  {'game': 96,
#   'data': '1993-05-11',
#   'serie': 'ECS',
#   'team': 'CHI',
#   'opp': 'CLE',
#   'game_number': '1',
#   'result': 'W (+7)',
#   'started': '1',
#   'minutes': '42:00',
#   'fg': '16',
#   'fga': '30',
#   'fgp': '.533',
#   'fg3': '0',
#   'fg3a': '4',
#   'fg3p': '.000',
#   'ft': '11',
#   'fta': '11',
#   'ftp': '1.000',
#   'orb': '0',
#   'drb': '0',
#   'totrb': '0',
#   'ast': '4',
#   'stl': '3',
#   'blk': '1',
#   'tov': '3',
#   'fouls': '3',
#   'points': '43'},
#  {'game': 97,
#   'data': '1993-05-13',
#   'serie': 'ECS',
#   'team': 'CHI',
#   'opp': 'CLE',
#   'game_number': '2',
#   'result': 'W (+19)',
#   'started': '1',
#   'minutes': '31:00',
#   'fg': '8',
#   'fga': '18',
#   'fgp': '.444',
#   'fg3': '0',
#   'fg3a': '2',
#   'fg3p': '.000',
#   'ft': '2',
#   'fta': '5',
#   'ftp': '.400',
#   'orb': '2',
#   'drb': '3',
#   'totrb': '5',
#   'ast': '6',
#   'stl': '2',
#   'blk': '0',
#   'tov': '2',
#   'fouls': '0',
#   'points': '18'},
#  {'game': 98,
#   'data': '1993-05-15',
#   'serie': 'ECS',
#   'team': 'CHI',
#   'opp': 'CLE',
#   'game_number': '3',
#   'result': 'W (+6)',
#   'started': '1',
#   'minutes': '40:00',
#   'fg': '12',
#   'fga': '24',
#   'fgp': '.500',
#   'fg3': '0',
#   'fg3a': '1',
#   'fg3p': '.000',
#   'ft': '8',
#   'fta': '10',
#   'ftp': '.800',
#   'orb': '2',
#   'drb': '4',
#   'totrb': '6',
#   'ast': '5',
#   'stl': '2',
#   'blk': '0',
#   'tov': '2',
#   'fouls': '1',
#   'points': '32'},
#  {'game': 99,
#   'data': '1993-05-17',
#   'serie': 'ECS',
#   'team': 'CHI',
#   'opp': 'CLE',
#   'game_number': '4',
#   'result': 'W (+2)',
#   'started': '1',
#   'minutes': '40:00',
#   'fg': '11',
#   'fga': '24',
#   'fgp': '.458',
#   'fg3': '2',
#   'fg3a': '2',
#   'fg3p': '1.000',
#   'ft': '7',
#   'fta': '9',
#   'ftp': '.778',
#   'orb': '3',
#   'drb': '6',
#   'totrb': '9',
#   'ast': '6',
#   'stl': '2',
#   'blk': '1',
#   'tov': '4',
#   'fouls': '2',
#   'points': '31'},
#  {'game': 100,
#   'data': '1993-05-23',
#   'serie': 'ECF',
#   'team': 'CHI',
#   'opp': 'NYK',
#   'game_number': '1',
#   'result': 'L (-8)',
#   'started': '1',
#   'minutes': '43:00',
#   'fg': '10',
#   'fga': '27',
#   'fgp': '.370',
#   'fg3': '2',
#   'fg3a': '4',
#   'fg3p': '.500',
#   'ft': '5',
#   'fta': '6',
#   'ftp': '.833',
#   'orb': '1',
#   'drb': '1',
#   'totrb': '2',
#   'ast': '5',
#   'stl': '4',
#   'blk': '0',
#   'tov': '1',
#   'fouls': '5',
#   'points': '27'},
#  {'game': 101,
#   'data': '1993-05-25',
#   'serie': 'ECF',
#   'team': 'CHI',
#   'opp': 'NYK',
#   'game_number': '2',
#   'result': 'L (-5)',
#   'started': '1',
#   'minutes': '39:00',
#   'fg': '12',
#   'fga': '32',
#   'fgp': '.375',
#   'fg3': '1',
#   'fg3a': '7',
#   'fg3p': '.143',
#   'ft': '11',
#   'fta': '13',
#   'ftp': '.846',
#   'orb': '3',
#   'drb': '6',
#   'totrb': '9',
#   'ast': '1',
#   'stl': '2',
#   'blk': '0',
#   'tov': '3',
#   'fouls': '3',
#   'points': '36'},
#  {'game': 102,
#   'data': '1993-05-29',
#   'serie': 'ECF',
#   'team': 'CHI',
#   'opp': 'NYK',
#   'game_number': '3',
#   'result': 'W (+20)',
#   'started': '1',
#   'minutes': '38:00',
#   'fg': '3',
#   'fga': '18',
#   'fgp': '.167',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3p': '',
#   'ft': '16',
#   'fta': '17',
#   'ftp': '.941',
#   'orb': '1',
#   'drb': '7',
#   'totrb': '8',
#   'ast': '11',
#   'stl': '2',
#   'blk': '2',
#   'tov': '2',
#   'fouls': '1',
#   'points': '22'},
#  {'game': 103,
#   'data': '1993-05-31',
#   'serie': 'ECF',
#   'team': 'CHI',
#   'opp': 'NYK',
#   'game_number': '4',
#   'result': 'W (+10)',
#   'started': '1',
#   'minutes': '39:00',
#   'fg': '18',
#   'fga': '30',
#   'fgp': '.600',
#   'fg3': '6',
#   'fg3a': '9',
#   'fg3p': '.667',
#   'ft': '12',
#   'fta': '14',
#   'ftp': '.857',
#   'orb': '0',
#   'drb': '6',
#   'totrb': '6',
#   'ast': '2',
#   'stl': '2',
#   'blk': '1',
#   'tov': '2',
#   'fouls': '5',
#   'points': '54'},
#  {'game': 104,
#   'data': '1993-06-02',
#   'serie': 'ECF',
#   'team': 'CHI',
#   'opp': 'NYK',
#   'game_number': '5',
#   'result': 'W (+3)',
#   'started': '1',
#   'minutes': '45:00',
#   'fg': '11',
#   'fga': '24',
#   'fgp': '.458',
#   'fg3': '0',
#   'fg3a': '1',
#   'fg3p': '.000',
#   'ft': '7',
#   'fta': '9',
#   'ftp': '.778',
#   'orb': '2',
#   'drb': '8',
#   'totrb': '10',
#   'ast': '14',
#   'stl': '2',
#   'blk': '1',
#   'tov': '5',
#   'fouls': '2',
#   'points': '29'},
#  {'game': 105,
#   'data': '1993-06-04',
#   'serie': 'ECF',
#   'team': 'CHI',
#   'opp': 'NYK',
#   'game_number': '6',
#   'result': 'W (+8)',
#   'started': '1',
#   'minutes': '45:00',
#   'fg': '8',
#   'fga': '24',
#   'fgp': '.333',
#   'fg3': '1',
#   'fg3a': '4',
#   'fg3p': '.250',
#   'ft': '8',
#   'fta': '9',
#   'ftp': '.889',
#   'orb': '0',
#   'drb': '2',
#   'totrb': '2',
#   'ast': '9',
#   'stl': '3',
#   'blk': '2',
#   'tov': '1',
#   'fouls': '4',
#   'points': '25'},
#  {'game': 106,
#   'data': '1993-06-09',
#   'serie': 'FIN',
#   'team': 'CHI',
#   'opp': 'PHO',
#   'game_number': '1',
#   'result': 'W (+8)',
#   'started': '1',
#   'minutes': '43:00',
#   'fg': '14',
#   'fga': '28',
#   'fgp': '.500',
#   'fg3': '0',
#   'fg3a': '1',
#   'fg3p': '.000',
#   'ft': '3',
#   'fta': '4',
#   'ftp': '.750',
#   'orb': '2',
#   'drb': '5',
#   'totrb': '7',
#   'ast': '5',
#   'stl': '5',
#   'blk': '1',
#   'tov': '2',
#   'fouls': '2',
#   'points': '31'},
#  {'game': 107,
#   'data': '1993-06-11',
#   'serie': 'FIN',
#   'team': 'CHI',
#   'opp': 'PHO',
#   'game_number': '2',
#   'result': 'W (+3)',
#   'started': '1',
#   'minutes': '40:00',
#   'fg': '18',
#   'fga': '36',
#   'fgp': '.500',
#   'fg3': '2',
#   'fg3a': '2',
#   'fg3p': '1.000',
#   'ft': '4',
#   'fta': '5',
#   'ftp': '.800',
#   'orb': '5',
#   'drb': '7',
#   'totrb': '12',
#   'ast': '9',
#   'stl': '2',
#   'blk': '0',
#   'tov': '5',
#   'fouls': '2',
#   'points': '42'},
#  {'game': 108,
#   'data': '1993-06-13',
#   'serie': 'FIN',
#   'team': 'CHI',
#   'opp': 'PHO',
#   'game_number': '3',
#   'result': 'L (-8)',
#   'started': '1',
#   'minutes': '57:00',
#   'fg': '19',
#   'fga': '43',
#   'fgp': '.442',
#   'fg3': '3',
#   'fg3a': '9',
#   'fg3p': '.333',
#   'ft': '3',
#   'fta': '6',
# ...
#   'game_number': '2',
#   'result': 'L (-8)',
#   'started': '1',
#   'minutes': '44:32',
#   'fg': '12',
#   'fga': '29',
#   'fgp': '.414',
#   'fg3': '0',
#   'fg3a': '6',
#   'fg3p': '.000',
#   'ft': '3',
#   'fta': '3',
#   'ftp': '1.000',
#   'orb': '6',
#   'drb': '10',
#   'totrb': '16',
#   'ast': '6',
#   'stl': '0',
#   'blk': '1',
#   'tov': '1',
#   'fouls': '2',
#   'points': '27'},
#  {'game': 145,
#   'data': '1997-05-10',
#   'serie': 'ECS',
#   'team': 'CHI',
#   'opp': 'ATL',
#   'game_number': '3',
#   'result': 'W (+20)',
#   'started': '1',
#   'minutes': '38:29',
#   'fg': '8',
#   'fga': '20',
#   'fgp': '.400',
#   'fg3': '0',
#   'fg3a': '1',
#   'fg3p': '.000',
#   'ft': '5',
#   'fta': '5',
#   'ftp': '1.000',
#   'orb': '3',
#   'drb': '6',
#   'totrb': '9',
#   'ast': '3',
#   'stl': '2',
#   'blk': '2',
#   'tov': '5',
#   'fouls': '3',
#   'points': '21'},
#  {'game': 146,
#   'data': '1997-05-11',
#   'serie': 'ECS',
#   'team': 'CHI',
#   'opp': 'ATL',
#   'game_number': '4',
#   'result': 'W (+9)',
#   'started': '1',
#   'minutes': '42:40',
#   'fg': '12',
#   'fga': '22',
#   'fgp': '.545',
#   'fg3': '0',
#   'fg3a': '2',
#   'fg3p': '.000',
#   'ft': '3',
#   'fta': '5',
#   'ftp': '.600',
#   'orb': '2',
#   'drb': '6',
#   'totrb': '8',
#   'ast': '4',
#   'stl': '2',
#   'blk': '1',
#   'tov': '5',
#   'fouls': '1',
#   'points': '27'},
#  {'game': 147,
#   'data': '1997-05-13',
#   'serie': 'ECS',
#   'team': 'CHI',
#   'opp': 'ATL',
#   'game_number': '5',
#   'result': 'W (+15)',
#   'started': '1',
#   'minutes': '40:29',
#   'fg': '9',
#   'fga': '23',
#   'fgp': '.391',
#   'fg3': '1',
#   'fg3a': '5',
#   'fg3p': '.200',
#   'ft': '5',
#   'fta': '5',
#   'ftp': '1.000',
#   'orb': '2',
#   'drb': '5',
#   'totrb': '7',
#   'ast': '7',
#   'stl': '2',
#   'blk': '0',
#   'tov': '2',
#   'fouls': '0',
#   'points': '24'},
#  {'game': 148,
#   'data': '1997-05-20',
#   'serie': 'ECF',
#   'team': 'CHI',
#   'opp': 'MIA',
#   'game_number': '1',
#   'result': 'W (+7)',
#   'started': '1',
#   'minutes': '42:10',
#   'fg': '15',
#   'fga': '31',
#   'fgp': '.484',
#   'fg3': '0',
#   'fg3a': '2',
#   'fg3p': '.000',
#   'ft': '7',
#   'fta': '10',
#   'ftp': '.700',
#   'orb': '3',
#   'drb': '6',
#   'totrb': '9',
#   'ast': '3',
#   'stl': '1',
#   'blk': '1',
#   'tov': '2',
#   'fouls': '3',
#   'points': '37'},
#  {'game': 149,
#   'data': '1997-05-22',
#   'serie': 'ECF',
#   'team': 'CHI',
#   'opp': 'MIA',
#   'game_number': '2',
#   'result': 'W (+7)',
#   'started': '1',
#   'minutes': '43:29',
#   'fg': '4',
#   'fga': '15',
#   'fgp': '.267',
#   'fg3': '0',
#   'fg3a': '1',
#   'fg3p': '.000',
#   'ft': '15',
#   'fta': '16',
#   'ftp': '.938',
#   'orb': '2',
#   'drb': '7',
#   'totrb': '9',
#   'ast': '3',
#   'stl': '4',
#   'blk': '1',
#   'tov': '2',
#   'fouls': '1',
#   'points': '23'},
#  {'game': 150,
#   'data': '1997-05-24',
#   'serie': 'ECF',
#   'team': 'CHI',
#   'opp': 'MIA',
#   'game_number': '3',
#   'result': 'W (+24)',
#   'started': '1',
#   'minutes': '36:06',
#   'fg': '14',
#   'fga': '25',
#   'fgp': '.560',
#   'fg3': '1',
#   'fg3a': '2',
#   'fg3p': '.500',
#   'ft': '5',
#   'fta': '5',
#   'ftp': '1.000',
#   'orb': '3',
#   'drb': '5',
#   'totrb': '8',
#   'ast': '1',
#   'stl': '1',
#   'blk': '0',
#   'tov': '3',
#   'fouls': '3',
#   'points': '34'},
#  {'game': 151,
#   'data': '1997-05-26',
#   'serie': 'ECF',
#   'team': 'CHI',
#   'opp': 'MIA',
#   'game_number': '4',
#   'result': 'L (-7)',
#   'started': '1',
#   'minutes': '44:42',
#   'fg': '9',
#   'fga': '35',
#   'fgp': '.257',
#   'fg3': '0',
#   'fg3a': '8',
#   'fg3p': '.000',
#   'ft': '11',
#   'fta': '13',
#   'ftp': '.846',
#   'orb': '4',
#   'drb': '4',
#   'totrb': '8',
#   'ast': '1',
#   'stl': '1',
#   'blk': '0',
#   'tov': '2',
#   'fouls': '2',
#   'points': '29'},
#  {'game': 152,
#   'data': '1997-05-28',
#   'serie': 'ECF',
#   'team': 'CHI',
#   'opp': 'MIA',
#   'game_number': '5',
#   'result': 'W (+13)',
#   'started': '1',
#   'minutes': '42:36',
#   'fg': '11',
#   'fga': '31',
#   'fgp': '.355',
#   'fg3': '1',
#   'fg3a': '4',
#   'fg3p': '.250',
#   'ft': '5',
#   'fta': '6',
#   'ftp': '.833',
#   'orb': '1',
#   'drb': '5',
#   'totrb': '6',
#   'ast': '5',
#   'stl': '2',
#   'blk': '2',
#   'tov': '4',
#   'fouls': '4',
#   'points': '28'},
#  {'game': 153,
#   'data': '1997-06-01',
#   'serie': 'FIN',
#   'team': 'CHI',
#   'opp': 'UTA',
#   'game_number': '1',
#   'result': 'W (+2)',
#   'started': '1',
#   'minutes': '40:52',
#   'fg': '13',
#   'fga': '27',
#   'fgp': '.481',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3p': '',
#   'ft': '5',
#   'fta': '7',
#   'ftp': '.714',
#   'orb': '1',
#   'drb': '3',
#   'totrb': '4',
#   'ast': '8',
#   'stl': '0',
#   'blk': '1',
#   'tov': '0',
#   'fouls': '3',
#   'points': '31'},
#  {'game': 154,
#   'data': '1997-06-04',
#   'serie': 'FIN',
#   'team': 'CHI',
#   'opp': 'UTA',
#   'game_number': '2',
#   'result': 'W (+12)',
#   'started': '1',
#   'minutes': '44:54',
#   'fg': '11',
#   'fga': '20',
#   'fgp': '.550',
#   'fg3': '1',
#   'fg3a': '2',
#   'fg3p': '.500',
#   'ft': '15',
#   'fta': '21',
#   'ftp': '.714',
#   'orb': '4',
#   'drb': '9',
#   'totrb': '13',
#   'ast': '9',
#   'stl': '2',
#   'blk': '0',
#   'tov': '5',
#   'fouls': '2',
#   'points': '38'},
#  {'game': 155,
#   'data': '1997-06-06',
#   'serie': 'FIN',
#   'team': 'CHI',
#   'opp': 'UTA',
#   'game_number': '3',
#   'result': 'L (-11)',
#   'started': '1',
#   'minutes': '40:31',
#   'fg': '9',
#   'fga': '22',
#   'fgp': '.409',
#   'fg3': '4',
#   'fg3a': '10',
#   'fg3p': '.400',
#   'ft': '4',
#   'fta': '5',
#   'ftp': '.800',
#   'orb': '0',
#   'drb': '3',
#   'totrb': '3',
#   'ast': '6',
#   'stl': '1',
#   'blk': '2',
#   'tov': '1',
#   'fouls': '1',
#   'points': '26'},
#  {'game': 156,
#   'data': '1997-06-08',
#   'serie': 'FIN',
#   'team': 'CHI',
#   'opp': 'UTA',
#   'game_number': '4',
#   'result': 'L (-5)',
#   'started': '1',
#   'minutes': '42:05',
#   'fg': '11',
#   'fga': '27',
#   'fgp': '.407',
#   'fg3': '0',
#   'fg3a': '4',
#   'fg3p': '.000',
#   'ft': '0',
#   'fta': '0',
#   'ftp': '',
#   'orb': '1',
#   'drb': '3',
#   'totrb': '4',
#   'ast': '4',
#   'stl': '0',
#   'blk': '0',
#   'tov': '3',
#   'fouls': '3',
#   'points': '22'},
#  {'game': 157,
#   'data': '1997-06-11',
#   'serie': 'FIN',
#   'team': 'CHI',
#   'opp': 'UTA',
#   'game_number': '5',
#   'result': 'W (+2)',
#   'started': '1',
#   'minutes': '44:17',
#   'fg': '13',
#   'fga': '27',
#   'fgp': '.481',
#   'fg3': '2',
#   'fg3a': '5',
#   'fg3p': '.400',
#   'ft': '10',
#   'fta': '12',
#   'ftp': '.833',
#   'orb': '2',
#   'drb': '5',
#   'totrb': '7',
#   'ast': '5',
#   'stl': '3',
#   'blk': '1',
#   'tov': '3',
#   'fouls': '3',
#   'points': '38'},
#  {'game': 158,
#   'data': '1997-06-13',
#   'serie': 'FIN',
#   'team': 'CHI',
#   'opp': 'UTA',
#   'game_number': '6',
#   'result': 'W (+4)',
#   'started': '1',
#   'minutes': '43:36',
#   'fg': '15',
#   'fga': '35',
#   'fgp': '.429',
#   'fg3': '1',
#   'fg3a': '4',
#   'fg3p': '.250',
#   'ft': '8',
#   'fta': '10',
#   'ftp': '.800',
#   'orb': '1',
#   'drb': '10',
#   'totrb': '11',
#   'ast': '4',
#   'stl': '1',
#   'blk': '1',
#   'tov': '1',
#   'fouls': '2',
#   'points': '39'},
#  {'game': 159,
#   'data': '1998-04-24',
#   'serie': 'EC1',
#   'team': 'CHI',
#   'opp': 'NJN',
#   'game_number': '1',
#   'result': 'W (+3)',
#   'started': '1',
#   'minutes': '47:29',
#   'fg': '11',
#   'fga': '27',
#   'fgp': '.407',
#   'fg3': '0',
#   'fg3a': '2',
#   'fg3p': '.000',
#   'ft': '17',
#   'fta': '23',
#   'ftp': '.739',
#   'orb': '0',
#   'drb': '7',
#   'totrb': '7',
#   'ast': '3',
#   'stl': '1',
#   'blk': '1',
#   'tov': '3',
#   'fouls': '1',
#   'points': '39'},
#  {'game': 160,
#   'data': '1998-04-26',
#   'serie': 'EC1',
#   'team': 'CHI',
#   'opp': 'NJN',
#   'game_number': '2',
#   'result': 'W (+5)',
#   'started': '1',
#   'minutes': '38:59',
#   'fg': '9',
#   'fga': '19',
#   'fgp': '.474',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3p': '',
#   'ft': '14',
#   'fta': '17',
#   'ftp': '.824',
#   'orb': '1',
#   'drb': '3',
#   'totrb': '4',
#   'ast': '2',
#   'stl': '1',
#   'blk': '1',
#   'tov': '5',
#   'fouls': '2',
#   'points': '32'},
#  {'game': 161,
#   'data': '1998-04-29',
#   'serie': 'EC1',
#   'team': 'CHI',
#   'opp': 'NJN',
#   'game_number': '3',
#   'result': 'W (+15)',
#   'started': '1',
#   'minutes': '43:40',
#   'fg': '16',
#   'fga': '22',
#   'fgp': '.727',
#   'fg3': '2',
#   'fg3a': '2',
#   'fg3p': '1.000',
#   'ft': '4',
#   'fta': '5',
#   'ftp': '.800',
#   'orb': '2',
#   'drb': '2',
#   'totrb': '4',
#   'ast': '3',
#   'stl': '2',
#   'blk': '1',
#   'tov': '2',
#   'fouls': '2',
#   'points': '38'},
#  {'game': 162,
#   'data': '1998-05-03',
#   'serie': 'ECS',
#   'team': 'CHI',
#   'opp': 'CHH',
#   'game_number': '1',
#   'result': 'W (+13)',
#   'started': '1',
#   'minutes': '44:21',
#   'fg': '11',
#   'fga': '26',
#   'fgp': '.423',
#   'fg3': '1',
#   'fg3a': '3',
#   'fg3p': '.333',
#   'ft': '12',
#   'fta': '14',
#   'ftp': '.857',
#   'orb': '4',
#   'drb': '7',
#   'totrb': '11',
#   'ast': '4',
#   'stl': '1',
#   'blk': '1',
#   'tov': '3',
#   'fouls': '0',
#   'points': '35'},
#  {'game': 163,
#   'data': '1998-05-06',
#   'serie': 'ECS',
#   'team': 'CHI',
#   'opp': 'CHH',
#   'game_number': '2',
#   'result': 'L (-2)',
#   'started': '1',
#   'minutes': '39:43',
#   'fg': '10',
#   'fga': '21',
#   'fgp': '.476',
#   'fg3': '0',
#   'fg3a': '3',
#   'fg3p': '.000',
#   'ft': '2',
#   'fta': '3',
#   'ftp': '.667',
#   'orb': '1',
#   'drb': '4',
#   'totrb': '5',
#   'ast': '6',
#   'stl': '0',
#   'blk': '0',
#   'tov': '0',
#   'fouls': '2',
#   'points': '22'},
#  {'game': 164,
#   'data': '1998-05-08',
#   'serie': 'ECS',
#   'team': 'CHI',
#   'opp': 'CHH',
#   'game_number': '3',
#   'result': 'W (+14)',
#   'started': '1',
#   'minutes': '38:55',
#   'fg': '9',
#   'fga': '20',
#   'fgp': '.450',
#   'fg3': '0',
#   'fg3a': '1',
#   'fg3p': '.000',
#   'ft': '9',
#   'fta': '10',
#   'ftp': '.900',
#   'orb': '3',
#   'drb': '2',
#   'totrb': '5',
#   'ast': '6',
#   'stl': '1',
#   'blk': '0',
#   'tov': '3',
#   'fouls': '3',
#   'points': '27'},
#  {'game': 165,
#   'data': '1998-05-10',
#   'serie': 'ECS',
#   'team': 'CHI',
#   'opp': 'CHH',
#   'game_number': '4',
#   'result': 'W (+14)',
#   'started': '1',
#   'minutes': '39:31',
#   'fg': '14',
#   'fga': '31',
#   'fgp': '.452',
#   'fg3': '0',
#   'fg3a': '1',
#   'fg3p': '.000',
#   'ft': '3',
#   'fta': '3',
#   'ftp': '1.000',
#   'orb': '0',
#   'drb': '3',
#   'totrb': '3',
#   'ast': '4',
#   'stl': '1',
#   'blk': '0',
#   'tov': '2',
#   'fouls': '1',
#   'points': '31'},
#  {'game': 166,
#   'data': '1998-05-13',
#   'serie': 'ECS',
#   'team': 'CHI',
#   'opp': 'CHH',
#   'game_number': '5',
#   'result': 'W (+9)',
#   'started': '1',
#   'minutes': '41:59',
#   'fg': '15',
#   'fga': '29',
#   'fgp': '.517',
#   'fg3': '0',
#   'fg3a': '3',
#   'fg3p': '.000',
#   'ft': '3',
#   'fta': '4',
#   'ftp': '.750',
#   'orb': '1',
#   'drb': '3',
#   'totrb': '4',
#   'ast': '3',
#   'stl': '2',
#   'blk': '1',
#   'tov': '0',
#   'fouls': '3',
#   'points': '33'},
#  {'game': 167,
#   'data': '1998-05-17',
#   'serie': 'ECF',
#   'team': 'CHI',
#   'opp': 'IND',
#   'game_number': '1',
#   'result': 'W (+6)',
#   'started': '1',
#   'minutes': '40:58',
#   'fg': '11',
#   'fga': '28',
#   'fgp': '.393',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3p': '',
#   'ft': '9',
#   'fta': '10',
#   'ftp': '.900',
#   'orb': '2',
#   'drb': '4',
#   'totrb': '6',
#   'ast': '1',
#   'stl': '5',
#   'blk': '0',
#   'tov': '1',
#   'fouls': '1',
#   'points': '31'},
#  {'game': 168,
#   'data': '1998-05-19',
#   'serie': 'ECF',
#   'team': 'CHI',
#   'opp': 'IND',
#   'game_number': '2',
#   'result': 'W (+6)',
#   'started': '1',
#   'minutes': '42:20',
#   'fg': '13',
#   'fga': '22',
#   'fgp': '.591',
#   'fg3': '0',
#   'fg3a': '1',
#   'fg3p': '.000',
#   'ft': '15',
#   'fta': '18',
#   'ftp': '.833',
#   'orb': '0',
#   'drb': '4',
#   'totrb': '4',
#   'ast': '5',
#   'stl': '4',
#   'blk': '0',
#   'tov': '0',
#   'fouls': '3',
#   'points': '41'},
#  {'game': 169,
#   'data': '1998-05-23',
#   'serie': 'ECF',
#   'team': 'CHI',
#   'opp': 'IND',
#   'game_number': '3',
#   'result': 'L (-2)',
#   'started': '1',
#   'minutes': '43:30',
#   'fg': '9',
#   'fga': '22',
#   'fgp': '.409',
#   'fg3': '2',
#   'fg3a': '3',
#   'fg3p': '.667',
#   'ft': '10',
#   'fta': '12',
#   'ftp': '.833',
#   'orb': '1',
#   'drb': '3',
#   'totrb': '4',
#   'ast': '7',
#   'stl': '1',
#   'blk': '0',
#   'tov': '5',
#   'fouls': '3',
#   'points': '30'},
#  {'game': 170,
#   'data': '1998-05-25',
#   'serie': 'ECF',
#   'team': 'CHI',
#   'opp': 'IND',
#   'game_number': '4',
#   'result': 'L (-2)',
#   'started': '1',
#   'minutes': '40:49',
#   'fg': '12',
#   'fga': '27',
#   'fgp': '.444',
#   'fg3': '1',
#   'fg3a': '3',
#   'fg3p': '.333',
#   'ft': '3',
#   'fta': '4',
#   'ftp': '.750',
#   'orb': '2',
#   'drb': '3',
#   'totrb': '5',
#   'ast': '2',
#   'stl': '0',
#   'blk': '2',
#   'tov': '6',
#   'fouls': '4',
#   'points': '28'},
#  {'game': 171,
#   'data': '1998-05-27',
#   'serie': 'ECF',
#   'team': 'CHI',
#   'opp': 'IND',
#   'game_number': '5',
#   'result': 'W (+19)',
#   'started': '1',
#   'minutes': '36:26',
#   'fg': '12',
#   'fga': '20',
#   'fgp': '.600',
#   'fg3': '2',
#   'fg3a': '4',
#   'fg3p': '.500',
#   'ft': '3',
#   'fta': '4',
#   'ftp': '.750',
#   'orb': '1',
#   'drb': '6',
#   'totrb': '7',
#   'ast': '4',
#   'stl': '1',
#   'blk': '1',
#   'tov': '0',
#   'fouls': '2',
#   'points': '29'},
#  {'game': 172,
#   'data': '1998-05-29',
#   'serie': 'ECF',
#   'team': 'CHI',
#   'opp': 'IND',
#   'game_number': '6',
#   'result': 'L (-3)',
#   'started': '1',
#   'minutes': '41:45',
#   'fg': '12',
#   'fga': '23',
#   'fgp': '.522',
#   'fg3': '1',
#   'fg3a': '4',
#   'fg3p': '.250',
#   'ft': '10',
#   'fta': '11',
#   'ftp': '.909',
#   'orb': '1',
#   'drb': '4',
#   'totrb': '5',
#   'ast': '2',
#   'stl': '1',
#   'blk': '0',
#   'tov': '3',
#   'fouls': '4',
#   'points': '35'},
#  {'game': 173,
#   'data': '1998-05-31',
#   'serie': 'ECF',
#   'team': 'CHI',
#   'opp': 'IND',
#   'game_number': '7',
#   'result': 'W (+5)',
#   'started': '1',
#   'minutes': '42:01',
#   'fg': '9',
#   'fga': '25',
#   'fgp': '.360',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3p': '',
#   'ft': '10',
#   'fta': '15',
#   'ftp': '.667',
#   'orb': '5',
#   'drb': '4',
#   'totrb': '9',
#   'ast': '8',
#   'stl': '0',
#   'blk': '0',
#   'tov': '2',
#   'fouls': '3',
#   'points': '28'},
#  {'game': 174,
#   'data': '1998-06-03',
#   'serie': 'FIN',
#   'team': 'CHI',
#   'opp': 'UTA',
#   'game_number': '1',
#   'result': 'L (-3)',
#   'started': '1',
#   'minutes': '45:36',
#   'fg': '13',
#   'fga': '29',
#   'fgp': '.448',
#   'fg3': '1',
#   'fg3a': '2',
#   'fg3p': '.500',
#   'ft': '6',
#   'fta': '8',
#   'ftp': '.750',
#   'orb': '1',
#   'drb': '2',
#   'totrb': '3',
#   'ast': '2',
#   'stl': '0',
#   'blk': '2',
#   'tov': '0',
#   'fouls': '3',
#   'points': '33'},
#  {'game': 175,
#   'data': '1998-06-05',
#   'serie': 'FIN',
#   'team': 'CHI',
#   'opp': 'UTA',
#   'game_number': '2',
#   'result': 'W (+5)',
#   'started': '1',
#   'minutes': '40:14',
#   'fg': '14',
#   'fga': '33',
#   'fgp': '.424',
#   'fg3': '0',
#   'fg3a': '2',
#   'fg3p': '.000',
#   'ft': '9',
#   'fta': '10',
#   'ftp': '.900',
#   'orb': '3',
#   'drb': '2',
#   'totrb': '5',
#   'ast': '3',
#   'stl': '1',
#   'blk': '1',
#   'tov': '0',
#   'fouls': '2',
#   'points': '37'},
#  {'game': 176,
#   'data': '1998-06-07',
#   'serie': 'FIN',
#   'team': 'CHI',
#   'opp': 'UTA',
#   'game_number': '3',
#   'result': 'W (+42)',
#   'started': '1',
#   'minutes': '32:06',
#   'fg': '7',
#   'fga': '14',
#   'fgp': '.500',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3p': '',
#   'ft': '10',
#   'fta': '11',
#   'ftp': '.909',
#   'orb': '1',
#   'drb': '2',
#   'totrb': '3',
#   'ast': '2',
#   'stl': '1',
#   'blk': '1',
#   'tov': '2',
#   'fouls': '1',
#   'points': '24'},
#  {'game': 177,
#   'data': '1998-06-10',
#   'serie': 'FIN',
#   'team': 'CHI',
#   'opp': 'UTA',
#   'game_number': '4',
#   'result': 'W (+4)',
#   'started': '1',
#   'minutes': '43:10',
#   'fg': '12',
#   'fga': '27',
#   'fgp': '.444',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3p': '',
#   'ft': '10',
#   'fta': '15',
#   'ftp': '.667',
#   'orb': '3',
#   'drb': '5',
#   'totrb': '8',
#   'ast': '2',
#   'stl': '2',
#   'blk': '0',
#   'tov': '3',
#   'fouls': '1',
#   'points': '34'},
#  {'game': 178,
#   'data': '1998-06-12',
#   'serie': 'FIN',
#   'team': 'CHI',
#   'opp': 'UTA',
#   'game_number': '5',
#   'result': 'L (-2)',
#   'started': '1',
#   'minutes': '44:43',
#   'fg': '9',
#   'fga': '26',
#   'fgp': '.346',
#   'fg3': '0',
#   'fg3a': '2',
#   'fg3p': '.000',
#   'ft': '10',
#   'fta': '11',
#   'ftp': '.909',
#   'orb': '1',
#   'drb': '3',
#   'totrb': '4',
#   'ast': '4',
#   'stl': '3',
#   'blk': '0',
#   'tov': '4',
#   'fouls': '4',
#   'points': '28'},
#  {'game': 179,
#   'data': '1998-06-14',
#   'serie': 'FIN',
#   'team': 'CHI',
#   'opp': 'UTA',
#   'game_number': '6',
#   'result': 'W (+1)',
#   'started': '1',
#   'minutes': '43:41',
#   'fg': '15',
#   'fga': '35',
#   'fgp': '.429',
#   'fg3': '3',
#   'fg3a': '7',
#   'fg3p': '.429',
#   'ft': '12',
#   'fta': '15',
#   'ftp': '.800',
#   'orb': '0',
#   'drb': '1',
#   'totrb': '1',
#   'ast': '1',
#   'stl': '4',
#   'blk': '0',
#   'tov': '1',
#   'fouls': '2',
#   'points': '45'}]

# %%
resume_lebron = []
url = "https://www.basketball-reference.com/players/j/jamesle01/gamelog-playoffs/"


response = requests.get(url, headers=headers)
text = response.text
soup = BeautifulSoup(text, 'html.parser')
    

list_games = soup.find('table', id ='pgl_basic_playoffs')
list_games = list_games.find('tbody')



games = list_games.findAll('tr')
add_game(games, resume_lebron)

# %%
len(resume_lebron)
# Out:
# 282

# %%
playoff_jordan = pd.DataFrame(resume_jordan)
playoff_lebron = pd.DataFrame(resume_lebron)

# %%
playoff_lebron
# Out:
#      game        data serie team  opp game_number   result started minutes  \
# 0       1  2006-04-22   EC1  CLE  WAS           1  W (+11)       1   48:00
# 1       2  2006-04-25   EC1  CLE  WAS           2   L (-5)       1   43:28
# 2       3  2006-04-28   EC1  CLE  WAS           3   W (+1)       1   47:37
# 3       4  2006-04-30   EC1  CLE  WAS           4  L (-10)       1   45:20
# 4       5  2006-05-03   EC1  CLE  WAS           5   W (+1)       1   46:07
# ..    ...         ...   ...  ...  ...         ...      ...     ...     ...
# 277   278  2023-05-12   WCS  LAL  GSW           6  W (+21)       1   43:08
# 278   279  2023-05-16   WCF  LAL  DEN           1   L (-6)       1   39:52
# 279   280  2023-05-18   WCF  LAL  DEN           2   L (-5)       1   40:08
# 280   281  2023-05-20   WCF  LAL  DEN           3  L (-11)       1   42:57
# 281   282  2023-05-22   WCF  LAL  DEN           4   L (-2)       1   47:56
#
#      fg  ...    ftp orb drb totrb ast stl blk tov fouls points
# 0    12  ...   .636   3   8    11  11   0   0   4     3     32
# 1     7  ...   .733   2   7     9   2   2   3  10     5     26
# 2    16  ...   .667   1   4     5   3   2   0   4     3     41
# 3    13  ...   .714   1   5     6   5   0   0   7     5     38
# 4    14  ...   .944   5   2     7   6   2   0   4     5     45
# ..   ..  ...    ...  ..  ..   ...  ..  ..  ..  ..   ...    ...
# 277  10  ...   .727   0   9     9   9   2   1   2     2     30
# 278   9  ...   .727   3   9    12   9   0   1   3     1     26
# 279   9  ...  1.000   0   9     9  10   4   2   3     2     22
# 280   8  ...   .571   0   7     7  12   0   0   2     2     23
# 281  15  ...   .857   2   8    10   9   2   0   1     1     40
#
# [282 rows x 27 columns]

# %%
playoff_jordan.to_csv('jordan_playoffs.csv', index=False)
playoff_lebron.to_csv('lebron_playoffs.csv', index=False)
